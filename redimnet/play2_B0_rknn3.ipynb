# %% [markdown]
# # small model

# %%
import torch
print(torch.__version__)
from torchsummary import summary


import torchaudio
import torchaudio.transforms as T

import torch.nn as nn
import torch.nn.functional as F

import numpy as np
# Out:
# 2.6.0+cu124

# %%
model_name='B0'
train_type='ft_lm'
dataset='vox2'

torch.hub.set_dir('/data/deep/redimnet/models')

original_model = torch.hub.load('IDRnD/ReDimNet', 'ReDimNet', 
                       model_name=model_name, 
                       train_type=train_type, 
                       dataset=dataset)
# Out:
# Using cache found in /data/deep/redimnet/models/IDRnD_ReDimNet_master
# /data/deep/redimnet/models/IDRnD_ReDimNet_master
# load_res : <All keys matched successfully>

# %% [markdown]
# *  ReDimNetWrap expects raw 16 kHz mono audio, exactly 32 000 samples

# %%
from torchinfo import summary
summary(original_model, input_size=(1, 32000))
# Out:
# /data/deep/redimnet/models/IDRnD_ReDimNet_master/redimnet/layers/features.py:137: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# ==============================================================================================================
# Layer (type:depth-idx)                                       Output Shape              Param #
# ==============================================================================================================
# ReDimNetWrap                                                 [1, 192]                  --
# ├─MelBanks: 1-1                                              [1, 60, 134]              --
# │    └─Sequential: 2-1                                       [1, 60, 134]              --
# │    │    └─Identity: 3-1                                    [1, 32000]                --
# │    │    └─PreEmphasis: 3-2                                 [1, 32000]                --
# │    │    └─MelSpectrogram: 3-3                              [1, 60, 134]              --
# ├─ReDimNet: 1-2                                              [1, 600, 134]             --
# │    └─Sequential: 2-2                                       [1, 600, 134]             --
# │    │    └─Conv2d: 3-4                                      [1, 10, 60, 134]          100
# │    │    └─LayerNorm: 3-5                                   [1, 10, 60, 134]          20
# │    │    └─to1d: 3-6                                        [1, 600, 134]             --
# │    └─Sequential: 2-3                                       [1, 600, 134]             --
# │    │    └─weigth1d: 3-7                                    [1, 600, 134]             (1)
# │    │    └─to2d: 3-8                                        [1, 10, 60, 134]          --
# │    │    └─Conv2d: 3-9                                      [1, 10, 60, 134]          110
# │    │    └─ConvBlock2d: 3-10                                [1, 10, 60, 134]          440
# │    │    └─ConvBlock2d: 3-11                                [1, 10, 60, 134]          440
# │    │    └─to1d: 3-12                                       [1, 600, 134]             --
# │    │    └─TimeContextBlock1d: 3-13                         [1, 600, 134]             31,500
# │    └─Sequential: 2-4                                       [1, 600, 134]             --
# │    │    └─weigth1d: 3-14                                   [1, 600, 134]             1,200
# │    │    └─to2d: 3-15                                       [1, 10, 60, 134]          --
# │    │    └─Conv2d: 3-16                                     [1, 40, 30, 134]          840
# │    │    └─ConvBlock2d: 3-17                                [1, 40, 30, 134]          4,160
# │    │    └─ConvBlock2d: 3-18                                [1, 40, 30, 134]          4,160
# │    │    └─ConvBlock2d: 3-19                                [1, 40, 30, 134]          4,160
# │    │    └─Sequential: 3-20                                 [1, 20, 30, 134]          840
# │    │    └─to1d: 3-21                                       [1, 600, 134]             --
# │    │    └─TimeContextBlock1d: 3-22                         [1, 600, 134]             31,500
# │    └─Sequential: 2-5                                       [1, 600, 134]             --
# │    │    └─weigth1d: 3-23                                   [1, 600, 134]             1,800
# │    │    └─to2d: 3-24                                       [1, 20, 30, 134]          --
# │    │    └─Conv2d: 3-25                                     [1, 60, 30, 134]          1,260
# │    │    └─ConvBlock2d: 3-26                                [1, 60, 30, 134]          8,640
# │    │    └─ConvBlock2d: 3-27                                [1, 60, 30, 134]          8,640
# │    │    └─ConvBlock2d: 3-28                                [1, 60, 30, 134]          8,640
# │    │    └─Sequential: 3-29                                 [1, 20, 30, 134]          1,020
# │    │    └─to1d: 3-30                                       [1, 600, 134]             --
# │    │    └─TimeContextBlock1d: 3-31                         [1, 600, 134]             31,500
# │    └─Sequential: 2-6                                       [1, 600, 134]             --
# │    │    └─weigth1d: 3-32                                   [1, 600, 134]             2,400
# │    │    └─to2d: 3-33                                       [1, 20, 30, 134]          --
# │    │    └─Conv2d: 3-34                                     [1, 80, 15, 134]          3,280
# │    │    └─ConvBlock2d: 3-35                                [1, 80, 15, 134]          14,720
# │    │    └─ConvBlock2d: 3-36                                [1, 80, 15, 134]          14,720
# │    │    └─ConvBlock2d: 3-37                                [1, 80, 15, 134]          14,720
# │    │    └─ConvBlock2d: 3-38                                [1, 80, 15, 134]          14,720
# │    │    └─Sequential: 3-39                                 [1, 40, 15, 134]          2,480
# │    │    └─to1d: 3-40                                       [1, 600, 134]             --
# │    │    └─TimeContextBlock1d: 3-41                         [1, 600, 134]             117,300
# │    └─Sequential: 2-7                                       [1, 600, 134]             --
# │    │    └─weigth1d: 3-42                                   [1, 600, 134]             3,000
# │    │    └─to2d: 3-43                                       [1, 40, 15, 134]          --
# │    │    └─Conv2d: 3-44                                     [1, 40, 15, 134]          1,640
# │    │    └─ConvBlock2d: 3-45                                [1, 40, 15, 134]          4,160
# │    │    └─ConvBlock2d: 3-46                                [1, 40, 15, 134]          4,160
# │    │    └─ConvBlock2d: 3-47                                [1, 40, 15, 134]          4,160
# │    │    └─to1d: 3-48                                       [1, 600, 134]             --
# │    │    └─TimeContextBlock1d: 3-49                         [1, 600, 134]             117,300
# │    └─weigth1d: 2-8                                         [1, 600, 134]             3,600
# │    └─Identity: 2-9                                         [1, 600, 134]             --
# │    └─Identity: 2-10                                        [1, 600, 134]             --
# ├─ASTP: 1-3                                                  [1, 1200]                 --
# │    └─Conv1d: 2-11                                          [1, 128, 134]             230,528
# │    └─Conv1d: 2-12                                          [1, 600, 134]             77,400
# ├─BatchNorm1d: 1-4                                           [1, 1200]                 2,400
# ├─Linear: 1-5                                                [1, 192]                  230,592
# ==============================================================================================================
# Total params: 1,004,251
# Trainable params: 1,004,250
# Non-trainable params: 1
# Total mult-adds (M): 406.29
# ==============================================================================================================
# Input size (MB): 0.13
# Forward/backward pass size (MB): 133.03
# Params size (MB): 4.02
# Estimated Total Size (MB): 137.18
# ==============================================================================================================

# %% [markdown]
# we can see MelSpectrogram inside the model ; lets take it outside the model;

# %%
for name, module in original_model.named_children():
    print(name, "=>", module)
# Out:
# backbone => ReDimNet(
#   (stem): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): LayerNorm(C=(10,), data_format=channels_first, eps=1e-06)
#     (2): to1d()
#   )
#   (stage0): Sequential(
#     (0): weigth1d(w=(1, 1, 1, 1),sequential=False)
#     (1): to2d(f=60,c=10)
#     (2): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#     (3): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=10, bias=False)
#         (conv1pw): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=10, bias=False)
#         (conv2pw): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (4): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=10, bias=False)
#         (conv1pw): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=10, bias=False)
#         (conv2pw): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (5): to1d()
#     (6): TimeContextBlock1d(
#       (red_dim_conv): Sequential(
#         (0): Conv1d(600, 20, kernel_size=(1,), stride=(1,))
#         (1): LayerNorm(C=(20,), data_format=channels_first, eps=1e-06)
#       )
#       (tcm): Sequential(
#         (0): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(7,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (1): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(19,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (2): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(31,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (3): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(59,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (4): TransformerEncoderLayer(
#           (attention): MultiHeadAttention(
#             (k_proj): Linear(in_features=20, out_features=20, bias=True)
#             (v_proj): Linear(in_features=20, out_features=20, bias=True)
#             (q_proj): Linear(in_features=20, out_features=20, bias=True)
#             (out_proj): Linear(in_features=20, out_features=20, bias=True)
#           )
#           (layer_norm): LayerNorm((20,), eps=1e-06, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): Linear(in_features=20, out_features=20, bias=True)
#             (intermediate_act_fn): NewGELUActivation()
#             (output_dense): Linear(in_features=20, out_features=20, bias=True)
#             (output_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((20,), eps=1e-06, elementwise_affine=True)
#         )
#       )
#       (exp_dim_conv): Conv1d(20, 600, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (stage1): Sequential(
#     (0): weigth1d(w=(1, 2, 600, 1),sequential=False)
#     (1): to2d(f=60,c=10)
#     (2): Conv2d(10, 40, kernel_size=(2, 1), stride=(2, 1))
#     (3): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (4): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (5): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (6): Sequential(
#       (0): Conv2d(40, 20, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=20)
#       (1): BatchNorm2d(20, eps=1e-06, momentum=0.1, affine=True, track_running_stats=True)
#       (2): GELU(approximate='none')
#       (3): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (7): to1d()
#     (8): TimeContextBlock1d(
#       (red_dim_conv): Sequential(
#         (0): Conv1d(600, 20, kernel_size=(1,), stride=(1,))
#         (1): LayerNorm(C=(20,), data_format=channels_first, eps=1e-06)
#       )
#       (tcm): Sequential(
#         (0): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(7,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (1): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(19,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (2): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(31,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (3): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(59,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (4): TransformerEncoderLayer(
#           (attention): MultiHeadAttention(
#             (k_proj): Linear(in_features=20, out_features=20, bias=True)
#             (v_proj): Linear(in_features=20, out_features=20, bias=True)
#             (q_proj): Linear(in_features=20, out_features=20, bias=True)
#             (out_proj): Linear(in_features=20, out_features=20, bias=True)
#           )
#           (layer_norm): LayerNorm((20,), eps=1e-06, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): Linear(in_features=20, out_features=20, bias=True)
#             (intermediate_act_fn): NewGELUActivation()
#             (output_dense): Linear(in_features=20, out_features=20, bias=True)
#             (output_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((20,), eps=1e-06, elementwise_affine=True)
#         )
#       )
#       (exp_dim_conv): Conv1d(20, 600, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (stage2): Sequential(
#     (0): weigth1d(w=(1, 3, 600, 1),sequential=False)
#     (1): to2d(f=30,c=20)
#     (2): Conv2d(20, 60, kernel_size=(1, 1), stride=(1, 1))
#     (3): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#         (conv1pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#         (conv2pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (4): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#         (conv1pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#         (conv2pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (5): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#         (conv1pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#         (conv2pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (6): Sequential(
#       (0): Conv2d(60, 20, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=20)
#       (1): BatchNorm2d(20, eps=1e-06, momentum=0.1, affine=True, track_running_stats=True)
#       (2): GELU(approximate='none')
#       (3): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (7): to1d()
#     (8): TimeContextBlock1d(
#       (red_dim_conv): Sequential(
#         (0): Conv1d(600, 20, kernel_size=(1,), stride=(1,))
#         (1): LayerNorm(C=(20,), data_format=channels_first, eps=1e-06)
#       )
#       (tcm): Sequential(
#         (0): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(7,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (1): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(19,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (2): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(31,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (3): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(20, 20, kernel_size=(59,), stride=(1,), padding=same, groups=20)
#           )
#           (norm): BatchNorm1d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#         )
#         (4): TransformerEncoderLayer(
#           (attention): MultiHeadAttention(
#             (k_proj): Linear(in_features=20, out_features=20, bias=True)
#             (v_proj): Linear(in_features=20, out_features=20, bias=True)
#             (q_proj): Linear(in_features=20, out_features=20, bias=True)
#             (out_proj): Linear(in_features=20, out_features=20, bias=True)
#           )
#           (layer_norm): LayerNorm((20,), eps=1e-06, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): Linear(in_features=20, out_features=20, bias=True)
#             (intermediate_act_fn): NewGELUActivation()
#             (output_dense): Linear(in_features=20, out_features=20, bias=True)
#             (output_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((20,), eps=1e-06, elementwise_affine=True)
#         )
#       )
#       (exp_dim_conv): Conv1d(20, 600, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (stage3): Sequential(
#     (0): weigth1d(w=(1, 4, 600, 1),sequential=False)
#     (1): to2d(f=30,c=20)
#     (2): Conv2d(20, 80, kernel_size=(2, 1), stride=(2, 1))
#     (3): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#         (conv1pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#         (conv2pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (4): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#         (conv1pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#         (conv2pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (5): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#         (conv1pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#         (conv2pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (6): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#         (conv1pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#         (conv2pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (7): Sequential(
#       (0): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=40)
#       (1): BatchNorm2d(40, eps=1e-06, momentum=0.1, affine=True, track_running_stats=True)
#       (2): GELU(approximate='none')
#       (3): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (8): to1d()
#     (9): TimeContextBlock1d(
#       (red_dim_conv): Sequential(
#         (0): Conv1d(600, 60, kernel_size=(1,), stride=(1,))
#         (1): LayerNorm(C=(60,), data_format=channels_first, eps=1e-06)
#       )
#       (tcm): Sequential(
#         (0): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(60, 60, kernel_size=(7,), stride=(1,), padding=same, groups=60)
#           )
#           (norm): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(60, 60, kernel_size=(1,), stride=(1,))
#         )
#         (1): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(60, 60, kernel_size=(19,), stride=(1,), padding=same, groups=60)
#           )
#           (norm): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(60, 60, kernel_size=(1,), stride=(1,))
#         )
#         (2): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(60, 60, kernel_size=(31,), stride=(1,), padding=same, groups=60)
#           )
#           (norm): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(60, 60, kernel_size=(1,), stride=(1,))
#         )
#         (3): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(60, 60, kernel_size=(59,), stride=(1,), padding=same, groups=60)
#           )
#           (norm): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(60, 60, kernel_size=(1,), stride=(1,))
#         )
#         (4): TransformerEncoderLayer(
#           (attention): MultiHeadAttention(
#             (k_proj): Linear(in_features=60, out_features=60, bias=True)
#             (v_proj): Linear(in_features=60, out_features=60, bias=True)
#             (q_proj): Linear(in_features=60, out_features=60, bias=True)
#             (out_proj): Linear(in_features=60, out_features=60, bias=True)
#           )
#           (layer_norm): LayerNorm((60,), eps=1e-06, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): Linear(in_features=60, out_features=60, bias=True)
#             (intermediate_act_fn): NewGELUActivation()
#             (output_dense): Linear(in_features=60, out_features=60, bias=True)
#             (output_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((60,), eps=1e-06, elementwise_affine=True)
#         )
#       )
#       (exp_dim_conv): Conv1d(60, 600, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (stage4): Sequential(
#     (0): weigth1d(w=(1, 5, 600, 1),sequential=False)
#     (1): to2d(f=15,c=40)
#     (2): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#     (3): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (4): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (5): ConvBlock2d(
#       (conv_block): ResBasicBlock(
#         (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#         (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#         (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (se): Identity()
#         (downsample): Identity()
#       )
#     )
#     (6): to1d()
#     (7): TimeContextBlock1d(
#       (red_dim_conv): Sequential(
#         (0): Conv1d(600, 60, kernel_size=(1,), stride=(1,))
#         (1): LayerNorm(C=(60,), data_format=channels_first, eps=1e-06)
#       )
#       (tcm): Sequential(
#         (0): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(60, 60, kernel_size=(7,), stride=(1,), padding=same, groups=60)
#           )
#           (norm): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(60, 60, kernel_size=(1,), stride=(1,))
#         )
#         (1): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(60, 60, kernel_size=(19,), stride=(1,), padding=same, groups=60)
#           )
#           (norm): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(60, 60, kernel_size=(1,), stride=(1,))
#         )
#         (2): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(60, 60, kernel_size=(31,), stride=(1,), padding=same, groups=60)
#           )
#           (norm): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(60, 60, kernel_size=(1,), stride=(1,))
#         )
#         (3): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv1d(60, 60, kernel_size=(59,), stride=(1,), padding=same, groups=60)
#           )
#           (norm): BatchNorm1d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv1d(60, 60, kernel_size=(1,), stride=(1,))
#         )
#         (4): TransformerEncoderLayer(
#           (attention): MultiHeadAttention(
#             (k_proj): Linear(in_features=60, out_features=60, bias=True)
#             (v_proj): Linear(in_features=60, out_features=60, bias=True)
#             (q_proj): Linear(in_features=60, out_features=60, bias=True)
#             (out_proj): Linear(in_features=60, out_features=60, bias=True)
#           )
#           (layer_norm): LayerNorm((60,), eps=1e-06, elementwise_affine=True)
#           (feed_forward): FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): Linear(in_features=60, out_features=60, bias=True)
#             (intermediate_act_fn): NewGELUActivation()
#             (output_dense): Linear(in_features=60, out_features=60, bias=True)
#             (output_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((60,), eps=1e-06, elementwise_affine=True)
#         )
#       )
#       (exp_dim_conv): Conv1d(60, 600, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (fin_wght1d): weigth1d(w=(1, 6, 600, 1),sequential=False)
#   (mfa): Identity()
#   (fin_to2d): Identity()
# )
# spec => MelBanks(
#   (torchfbank): Sequential(
#     (0): Identity()
#     (1): PreEmphasis()
#     (2): MelSpectrogram(
#       (spectrogram): Spectrogram()
#       (mel_scale): MelScale()
#     )
#   )
#   (specaug): Identity()
# )
# pool => ASTP(
#   (linear1): Conv1d(1800, 128, kernel_size=(1,), stride=(1,))
#   (linear2): Conv1d(128, 600, kernel_size=(1,), stride=(1,))
# )
# bn => BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# linear => Linear(in_features=1200, out_features=192, bias=True)

# %% [markdown]
# # create new model

# %%
class Conv1dTo2d(nn.Module):
    def __init__(self, conv1d_layer):
        super().__init__()

        # Compute kernel and padding
        k = conv1d_layer.kernel_size[0]
        s = conv1d_layer.stride[0]
        d = conv1d_layer.dilation[0]

        if isinstance(conv1d_layer.padding, str) and conv1d_layer.padding == 'same':
            # SAME padding formula: pad = ((stride - 1) * input - stride + kernel + (kernel-1)*(d-1)) // 2
            # But we can't infer input shape at init. So, use padding='same' during forward.
            self.use_same_padding = True
            padding = 0
        else:
            self.use_same_padding = False
            padding = conv1d_layer.padding[0]

        self.k = k
        self.s = s
        self.d = d

        self.conv2d = nn.Conv2d(
            in_channels=conv1d_layer.in_channels,
            out_channels=conv1d_layer.out_channels,
            kernel_size=(1, k),
            stride=(1, s),
            padding=(0, padding),
            dilation=(1, d),
            groups=conv1d_layer.groups,
            bias=conv1d_layer.bias is not None
        )
        self.conv2d.weight.data.copy_(conv1d_layer.weight.data.unsqueeze(2))
        if conv1d_layer.bias is not None:
            self.conv2d.bias.data.copy_(conv1d_layer.bias.data)

    def forward(self, x):  # [B, C, T]
        x = x.unsqueeze(2)  # → [B, C, 1, T]

        if self.use_same_padding:
            # Dynamic SAME padding for width
            L_in = x.shape[-1]
            pad_total = max((L_in - 1) * self.s + (self.k - 1) * self.d + 1 - L_in, 0)
            pad_left = pad_total // 2
            pad_right = pad_total - pad_left
            x = F.pad(x, (pad_left, pad_right))

        x = self.conv2d(x)   # → [B, C_out, 1, T_out]
        return x.squeeze(2)  # → [B, C_out, T_out]


class BatchNorm1dTo2d(nn.Module):
    def __init__(self, bn1d):
        super().__init__()
        self.bn2d = nn.BatchNorm2d(bn1d.num_features)
        self.bn2d.weight.data.copy_(bn1d.weight.data)
        self.bn2d.bias.data.copy_(bn1d.bias.data)
        self.bn2d.running_mean.data.copy_(bn1d.running_mean.data)
        self.bn2d.running_var.data.copy_(bn1d.running_var.data)

    def forward(self, x):  # [B, C, T]
        x = x.unsqueeze(2)        # [B, C, 1, T]
        x = self.bn2d(x)          # [B, C, 1, T]
        return x.squeeze(2)       # [B, C, T]

class LayerNormChannelsFirst(nn.Module):
    """Replace LayerNorm(C, channels_first) → channels_last permute."""
    def __init__(self, num_channels, eps=1e-6):
        super().__init__()
        self.norm = nn.LayerNorm(num_channels, eps=eps)

    def forward(self, x):  # [B, C, T]
        x = x.permute(0, 2, 1)     # → [B, T, C]
        x = self.norm(x)          # → [B, T, C]
        return x.permute(0, 2, 1) # → [B, C, T]

class ConvNeXtLikeBlockSafe(nn.Module):
    def __init__(self, block):
        super().__init__()
        self.dwconv = Conv1dTo2d(block.dwconvs[0])
        self.norm = BatchNorm1dTo2d(block.norm)
        self.act = nn.GELU()  # You may swap to ReLU if needed
        self.pwconv = Conv1dTo2d(block.pwconv1)

    def forward(self, x):
        x = self.dwconv(x)
        x = self.norm(x)
        x = self.act(x)
        x = self.pwconv(x)
        return x

class AttentionMock(nn.Module):
    """Replace Transformer attention with grouped Conv1d (preserve dimensions)."""
    def __init__(self, in_features):
        super().__init__()
        self.fake_attn = nn.Conv1d(in_features, in_features, kernel_size=1, groups=1)

    def forward(self, x):  # [B, C, T]
        return self.fake_attn(x)

class TimeContextBlock1dSafe(nn.Module):
    def __init__(self, original):
        super().__init__()

        in_ch = original.red_dim_conv[0].in_channels
        mid_ch = original.red_dim_conv[0].out_channels
        out_ch = original.exp_dim_conv.out_channels

        self.red_dim_conv = nn.Sequential(
            Conv1dTo2d(original.red_dim_conv[0]),
            BatchNorm1dTo2d(nn.BatchNorm1d(mid_ch))  # use BN instead of LayerNorm
        )

        self.tcm = nn.Sequential(
            ConvNeXtLikeBlockSafe(original.tcm[0]),
            ConvNeXtLikeBlockSafe(original.tcm[1]),
            ConvNeXtLikeBlockSafe(original.tcm[2]),
            ConvNeXtLikeBlockSafe(original.tcm[3]),
            AttentionMock(mid_ch)  # same channels
        )

        self.exp_dim_conv = Conv1dTo2d(original.exp_dim_conv)

    def forward(self, x):  # [B, C, T]
        x = self.red_dim_conv(x)
        x = self.tcm(x)
        x = self.exp_dim_conv(x)
        return x

# %%
########################################
# 2) Define a Model Class without MelBanks
########################################
import torch
import torch.nn as nn

class ReDimNetNoMel(nn.Module):
    """
    A wrapper around the original ReDimNetWrap that:
      - Excludes the 'spec' (MelBanks) module
      - Uses 'backbone', 'pool', 'bn', and 'linear'
    We expect a precomputed mel spectrogram as input with shape [B, 1, n_mels, time_frames].
    """
    def __init__(self, original_wrap):
        super().__init__()
        
        # Grab references to the submodules we want to keep
        self.backbone = original_wrap.backbone
        
        ## fix rKNN layers
        self.backbone.stage0[6] = TimeContextBlock1dSafe(original_wrap.backbone.stage0[6])
        self.backbone.stage1[8] = TimeContextBlock1dSafe(original_wrap.backbone.stage1[8])
        self.backbone.stage2[8] = TimeContextBlock1dSafe(original_wrap.backbone.stage2[8])
        self.backbone.stage3[9] = TimeContextBlock1dSafe(original_wrap.backbone.stage3[9])
        self.backbone.stage4[7] = TimeContextBlock1dSafe(original_wrap.backbone.stage4[7])
        
        # Replace ASTP with RKNN-safe version:
        self.pool = original_wrap.pool
        self.bn = original_wrap.bn
        self.linear = original_wrap.linear

    def forward(self, x):
        # x: shape [B, 1, n_mels, time_frames]
        # (1) Pass through the backbone
        x = self.backbone(x)    # shape might become [B, channels, frames] or similar
        print("Backbone output shape:", x.shape)  # ADD THIS LINE
        # (2) Pooling
        x = self.pool(x)        # ASTP => shape likely [B, embedding_dim]
        # (3) BatchNorm
        x = self.bn(x)
        # (4) Final linear => 192-dim (if that's your embedding size)
        x = self.linear(x)
        return x


# Create an instance of our new model that skips the MelBanks front-end
model_no_mel = ReDimNetNoMel(original_model)

# %%
model_no_mel.eval()  # <- this line is critical!
dummy = torch.randn(1, 1, 60, 200)
model_no_mel(dummy)
# Out:
# Backbone output shape: torch.Size([1, 600, 200])
# tensor([[ 1.4188e+00,  1.2236e+00, -2.9876e+00, -3.2038e-01,  2.2456e+00,
#           3.2745e-01, -1.6817e+00,  2.4041e+00, -6.7343e-01,  6.1326e+00,
#           3.2302e+00,  1.1605e+00, -3.2753e+00, -1.1229e+01, -2.0745e+00,
#           2.5688e+00, -6.9183e+00, -2.9781e+00, -1.6287e+00, -4.9674e+00,
#           3.8377e-01,  4.8111e+00,  4.5199e+00, -1.9576e-01,  6.5155e+00,
#          -3.8177e+00, -1.4541e+00, -2.1312e+00,  1.2289e-01, -5.7385e+00,
#          -5.1009e+00, -2.8753e+00, -5.4152e+00,  5.5775e+00, -2.9733e-01,
#          -1.7650e+00, -4.0334e+00,  6.1912e-01,  8.9446e+00, -2.0726e+00,
#          -2.1357e+00,  1.8274e+00,  3.8877e+00, -3.8785e+00,  1.2614e+01,
#           1.5692e+00, -1.6225e+00, -1.6440e+00,  5.7167e+00, -9.6196e-01,
#           3.0724e+00, -5.2655e+00, -9.0852e-01,  7.9624e+00, -2.8988e+00,
#          -8.3127e+00, -5.7682e-01,  2.7019e+00, -1.8687e+00,  2.1444e-01,
#           5.3304e-01, -3.1506e+00,  3.7241e+00, -3.7463e+00,  1.1921e+01,
#          -1.0311e+00, -1.8798e+00,  5.4293e+00, -2.1924e+00, -5.8000e+00,
#           2.5717e+00,  6.7033e-01, -3.5780e+00,  1.8310e+00, -1.4329e+00,
#          -2.2963e+00, -1.4456e-01,  9.6349e-03, -4.5559e+00, -1.0821e+00,
#          -1.1031e+01,  4.0862e+00, -1.1541e+00,  5.8974e+00,  7.8341e+00,
#           2.9244e+00,  1.6582e+00, -3.3552e+00, -4.0757e-02,  2.8751e+00,
#          -5.4705e+00, -2.3782e+00,  5.1398e+00,  2.4131e+00, -3.7220e+00,
#          -1.9484e+00,  2.7059e+00, -2.3738e-01,  1.9768e+00, -5.5917e+00,
#           5.8190e+00,  7.0893e+00, -3.3170e+00, -3.8875e+00,  1.4540e+00,
#          -3.8020e+00,  2.6724e-01,  2.8039e+00,  4.0973e+00, -3.9028e+00,
#          -5.3441e+00, -1.8259e+00, -1.6725e+00, -3.9853e+00,  1.5292e+00,
#           2.9707e+00, -2.0084e+00, -4.1658e+00, -5.6644e-01,  3.8493e+00,
#          -4.1419e+00,  2.0469e+00,  9.0997e-01, -2.0372e+00, -5.0551e+00,
#          -4.2732e+00,  1.4539e+00,  8.2169e-01,  1.3395e+00,  4.2309e+00,
#          -1.6985e+00,  1.0415e+00,  1.6930e+00,  3.7584e+00, -1.1604e+00,
#          -1.7278e+00,  4.0055e+00,  6.4473e+00,  2.9391e+00,  5.1179e-01,
#           3.1989e+00, -3.2665e+00, -1.3758e-01, -1.3581e+00, -2.6196e+00,
#          -2.7324e+00, -2.4779e+00,  8.6424e+00, -4.3850e+00, -3.5934e+00,
#          -6.2388e+00,  2.2812e+00,  2.6095e+00,  2.1122e+00,  9.8233e-01,
#          -6.7585e-01,  3.1923e+00, -9.2204e-01,  4.8376e+00, -9.0643e+00,
#          -1.0825e+00, -1.4802e+00,  1.3560e-01, -6.1070e+00, -2.7115e+00,
#          -3.5689e+00,  2.3555e+00,  3.0739e-01, -5.9005e+00,  2.5352e+00,
#          -9.6558e-01,  7.0629e-02, -1.0697e-01, -6.6274e+00,  6.0223e+00,
#           5.3083e-01,  1.9882e-01, -2.5065e-01,  1.7361e+00, -1.3410e+00,
#           2.5760e+00,  2.6069e+00, -9.0447e+00,  1.7731e-03,  2.4149e+00,
#           3.3140e-01,  4.1601e+00, -6.5943e+00,  9.1360e+00,  7.2204e-01,
#           1.8898e+00,  9.1837e+00]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## layres debug

# %%
for name, module in model_no_mel.named_modules():
    if isinstance(module, nn.LayerNorm):
        print("❌ Still has LayerNorm at:", name)

# %%
print("stage0.6 =", model_no_mel.backbone.stage0[6])
# Out:
# stage0.6 = TimeContextBlock1dSafe(
#   (red_dim_conv): Sequential(
#     (0): Conv1dTo2d(
#       (conv2d): Conv2d(600, 20, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): BatchNorm1dTo2d(
#       (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (tcm): Sequential(
#     (0): ConvNeXtLikeBlockSafe(
#       (dwconv): Conv1dTo2d(
#         (conv2d): Conv2d(20, 20, kernel_size=(1, 7), stride=(1, 1), groups=20)
#       )
#       (norm): BatchNorm1dTo2d(
#         (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): GELU(approximate='none')
#       (pwconv): Conv1dTo2d(
#         (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (1): ConvNeXtLikeBlockSafe(
#       (dwconv): Conv1dTo2d(
#         (conv2d): Conv2d(20, 20, kernel_size=(1, 19), stride=(1, 1), groups=20)
#       )
#       (norm): BatchNorm1dTo2d(
#         (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): GELU(approximate='none')
#       (pwconv): Conv1dTo2d(
#         (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (2): ConvNeXtLikeBlockSafe(
#       (dwconv): Conv1dTo2d(
#         (conv2d): Conv2d(20, 20, kernel_size=(1, 31), stride=(1, 1), groups=20)
#       )
#       (norm): BatchNorm1dTo2d(
#         (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): GELU(approximate='none')
#       (pwconv): Conv1dTo2d(
#         (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (3): ConvNeXtLikeBlockSafe(
#       (dwconv): Conv1dTo2d(
#         (conv2d): Conv2d(20, 20, kernel_size=(1, 59), stride=(1, 1), groups=20)
#       )
#       (norm): BatchNorm1dTo2d(
#         (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (act): GELU(approximate='none')
#       (pwconv): Conv1dTo2d(
#         (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (4): AttentionMock(
#       (fake_attn): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (exp_dim_conv): Conv1dTo2d(
#     (conv2d): Conv2d(20, 600, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# ## info

# %%
model_no_mel.eval()
# Out:
# ReDimNetNoMel(
#   (backbone): ReDimNet(
#     (stem): Sequential(
#       (0): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): LayerNorm(C=(10,), data_format=channels_first, eps=1e-06)
#       (2): to1d()
#     )
#     (stage0): Sequential(
#       (0): weigth1d(w=(1, 1, 1, 1),sequential=False)
#       (1): to2d(f=60,c=10)
#       (2): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#       (3): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=10, bias=False)
#           (conv1pw): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=10, bias=False)
#           (conv2pw): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=10, bias=False)
#           (conv1pw): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=10, bias=False)
#           (conv2pw): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (5): to1d()
#       (6): TimeContextBlock1dSafe(
#         (red_dim_conv): Sequential(
#           (0): Conv1dTo2d(
#             (conv2d): Conv2d(600, 20, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): BatchNorm1dTo2d(
#             (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 7), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 19), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (2): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 31), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (3): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 59), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): AttentionMock(
#             (fake_attn): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (exp_dim_conv): Conv1dTo2d(
#           (conv2d): Conv2d(20, 600, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (stage1): Sequential(
#       (0): weigth1d(w=(1, 2, 600, 1),sequential=False)
#       (1): to2d(f=60,c=10)
#       (2): Conv2d(10, 40, kernel_size=(2, 1), stride=(2, 1))
#       (3): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (5): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (6): Sequential(
#         (0): Conv2d(40, 20, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=20)
#         (1): BatchNorm2d(20, eps=1e-06, momentum=0.1, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#         (3): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (7): to1d()
#       (8): TimeContextBlock1dSafe(
#         (red_dim_conv): Sequential(
#           (0): Conv1dTo2d(
#             (conv2d): Conv2d(600, 20, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): BatchNorm1dTo2d(
#             (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 7), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 19), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (2): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 31), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (3): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 59), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): AttentionMock(
#             (fake_attn): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (exp_dim_conv): Conv1dTo2d(
#           (conv2d): Conv2d(20, 600, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (stage2): Sequential(
#       (0): weigth1d(w=(1, 3, 600, 1),sequential=False)
#       (1): to2d(f=30,c=20)
#       (2): Conv2d(20, 60, kernel_size=(1, 1), stride=(1, 1))
#       (3): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#           (conv1pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#           (conv2pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#           (conv1pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#           (conv2pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (5): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#           (conv1pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(60, 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=60, bias=False)
#           (conv2pw): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (6): Sequential(
#         (0): Conv2d(60, 20, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=20)
#         (1): BatchNorm2d(20, eps=1e-06, momentum=0.1, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#         (3): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (7): to1d()
#       (8): TimeContextBlock1dSafe(
#         (red_dim_conv): Sequential(
#           (0): Conv1dTo2d(
#             (conv2d): Conv2d(600, 20, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): BatchNorm1dTo2d(
#             (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 7), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 19), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (2): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 31), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (3): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 59), stride=(1, 1), groups=20)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(20, 20, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): AttentionMock(
#             (fake_attn): Conv1d(20, 20, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (exp_dim_conv): Conv1dTo2d(
#           (conv2d): Conv2d(20, 600, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (stage3): Sequential(
#       (0): weigth1d(w=(1, 4, 600, 1),sequential=False)
#       (1): to2d(f=30,c=20)
#       (2): Conv2d(20, 80, kernel_size=(2, 1), stride=(2, 1))
#       (3): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (conv1pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (conv2pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (conv1pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (conv2pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (5): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (conv1pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (conv2pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (6): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (conv1pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(80, 80, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=80, bias=False)
#           (conv2pw): Conv2d(80, 80, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (7): Sequential(
#         (0): Conv2d(80, 40, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=40)
#         (1): BatchNorm2d(40, eps=1e-06, momentum=0.1, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#         (3): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (8): to1d()
#       (9): TimeContextBlock1dSafe(
#         (red_dim_conv): Sequential(
#           (0): Conv1dTo2d(
#             (conv2d): Conv2d(600, 60, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): BatchNorm1dTo2d(
#             (bn2d): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 7), stride=(1, 1), groups=60)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 19), stride=(1, 1), groups=60)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (2): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 31), stride=(1, 1), groups=60)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (3): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 59), stride=(1, 1), groups=60)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): AttentionMock(
#             (fake_attn): Conv1d(60, 60, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (exp_dim_conv): Conv1dTo2d(
#           (conv2d): Conv2d(60, 600, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (stage4): Sequential(
#       (0): weigth1d(w=(1, 5, 600, 1),sequential=False)
#       (1): to2d(f=15,c=40)
#       (2): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#       (3): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (5): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv1pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=40, bias=False)
#           (conv2pw): Conv2d(40, 40, kernel_size=(1, 1), stride=(1, 1))
#           (bn2): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): Identity()
#           (downsample): Identity()
#         )
#       )
#       (6): to1d()
#       (7): TimeContextBlock1dSafe(
#         (red_dim_conv): Sequential(
#           (0): Conv1dTo2d(
#             (conv2d): Conv2d(600, 60, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): BatchNorm1dTo2d(
#             (bn2d): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 7), stride=(1, 1), groups=60)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (1): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 19), stride=(1, 1), groups=60)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (2): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 31), stride=(1, 1), groups=60)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (3): ConvNeXtLikeBlockSafe(
#             (dwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 59), stride=(1, 1), groups=60)
#             )
#             (norm): BatchNorm1dTo2d(
#               (bn2d): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (act): GELU(approximate='none')
#             (pwconv): Conv1dTo2d(
#               (conv2d): Conv2d(60, 60, kernel_size=(1, 1), stride=(1, 1))
#             )
#           )
#           (4): AttentionMock(
#             (fake_attn): Conv1d(60, 60, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (exp_dim_conv): Conv1dTo2d(
#           (conv2d): Conv2d(60, 600, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#     )
#     (fin_wght1d): weigth1d(w=(1, 6, 600, 1),sequential=False)
#     (mfa): Identity()
#     (fin_to2d): Identity()
#   )
#   (pool): ASTP(
#     (linear1): Conv1d(1800, 128, kernel_size=(1,), stride=(1,))
#     (linear2): Conv1d(128, 600, kernel_size=(1,), stride=(1,))
#   )
#   (bn): BatchNorm1d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear): Linear(in_features=1200, out_features=192, bias=True)
# )

# %%
summary(model_no_mel, (1, 1, 60, 200))
# Out:
# Backbone output shape: torch.Size([1, 600, 200])
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# ReDimNetNoMel                                           [1, 192]                  --
# ├─ReDimNet: 1-1                                         [1, 600, 200]             --
# │    └─Sequential: 2-1                                  [1, 600, 200]             --
# │    │    └─Conv2d: 3-1                                 [1, 10, 60, 200]          100
# │    │    └─LayerNorm: 3-2                              [1, 10, 60, 200]          20
# │    │    └─to1d: 3-3                                   [1, 600, 200]             --
# │    └─Sequential: 2-2                                  [1, 600, 200]             --
# │    │    └─weigth1d: 3-4                               [1, 600, 200]             (1)
# │    │    └─to2d: 3-5                                   [1, 10, 60, 200]          --
# │    │    └─Conv2d: 3-6                                 [1, 10, 60, 200]          110
# │    │    └─ConvBlock2d: 3-7                            [1, 10, 60, 200]          440
# │    │    └─ConvBlock2d: 3-8                            [1, 10, 60, 200]          440
# │    │    └─to1d: 3-9                                   [1, 600, 200]             --
# │    │    └─TimeContextBlock1dSafe: 3-10                [1, 600, 200]             29,320
# │    └─Sequential: 2-3                                  [1, 600, 200]             --
# │    │    └─weigth1d: 3-11                              [1, 600, 200]             1,200
# │    │    └─to2d: 3-12                                  [1, 10, 60, 200]          --
# │    │    └─Conv2d: 3-13                                [1, 40, 30, 200]          840
# │    │    └─ConvBlock2d: 3-14                           [1, 40, 30, 200]          4,160
# │    │    └─ConvBlock2d: 3-15                           [1, 40, 30, 200]          4,160
# │    │    └─ConvBlock2d: 3-16                           [1, 40, 30, 200]          4,160
# │    │    └─Sequential: 3-17                            [1, 20, 30, 200]          840
# │    │    └─to1d: 3-18                                  [1, 600, 200]             --
# │    │    └─TimeContextBlock1dSafe: 3-19                [1, 600, 200]             29,320
# │    └─Sequential: 2-4                                  [1, 600, 200]             --
# │    │    └─weigth1d: 3-20                              [1, 600, 200]             1,800
# │    │    └─to2d: 3-21                                  [1, 20, 30, 200]          --
# │    │    └─Conv2d: 3-22                                [1, 60, 30, 200]          1,260
# │    │    └─ConvBlock2d: 3-23                           [1, 60, 30, 200]          8,640
# │    │    └─ConvBlock2d: 3-24                           [1, 60, 30, 200]          8,640
# │    │    └─ConvBlock2d: 3-25                           [1, 60, 30, 200]          8,640
# │    │    └─Sequential: 3-26                            [1, 20, 30, 200]          1,020
# │    │    └─to1d: 3-27                                  [1, 600, 200]             --
# │    │    └─TimeContextBlock1dSafe: 3-28                [1, 600, 200]             29,320
# │    └─Sequential: 2-5                                  [1, 600, 200]             --
# │    │    └─weigth1d: 3-29                              [1, 600, 200]             2,400
# │    │    └─to2d: 3-30                                  [1, 20, 30, 200]          --
# │    │    └─Conv2d: 3-31                                [1, 80, 15, 200]          3,280
# │    │    └─ConvBlock2d: 3-32                           [1, 80, 15, 200]          14,720
# │    │    └─ConvBlock2d: 3-33                           [1, 80, 15, 200]          14,720
# │    │    └─ConvBlock2d: 3-34                           [1, 80, 15, 200]          14,720
# │    │    └─ConvBlock2d: 3-35                           [1, 80, 15, 200]          14,720
# │    │    └─Sequential: 3-36                            [1, 40, 15, 200]          2,480
# │    │    └─to1d: 3-37                                  [1, 600, 200]             --
# │    │    └─TimeContextBlock1dSafe: 3-38                [1, 600, 200]             98,760
# │    └─Sequential: 2-6                                  [1, 600, 200]             --
# │    │    └─weigth1d: 3-39                              [1, 600, 200]             3,000
# │    │    └─to2d: 3-40                                  [1, 40, 15, 200]          --
# │    │    └─Conv2d: 3-41                                [1, 40, 15, 200]          1,640
# │    │    └─ConvBlock2d: 3-42                           [1, 40, 15, 200]          4,160
# │    │    └─ConvBlock2d: 3-43                           [1, 40, 15, 200]          4,160
# │    │    └─ConvBlock2d: 3-44                           [1, 40, 15, 200]          4,160
# │    │    └─to1d: 3-45                                  [1, 600, 200]             --
# │    │    └─TimeContextBlock1dSafe: 3-46                [1, 600, 200]             98,760
# │    └─weigth1d: 2-7                                    [1, 600, 200]             3,600
# │    └─Identity: 2-8                                    [1, 600, 200]             --
# │    └─Identity: 2-9                                    [1, 600, 200]             --
# ├─ASTP: 1-2                                             [1, 1200]                 --
# │    └─Conv1d: 2-10                                     [1, 128, 200]             230,528
# │    └─Conv1d: 2-11                                     [1, 600, 200]             77,400
# ├─BatchNorm1d: 1-3                                      [1, 1200]                 2,400
# ├─Linear: 1-4                                           [1, 192]                  230,592
# =========================================================================================================
# Total params: 960,631
# Trainable params: 960,630
# Non-trainable params: 1
# Total mult-adds (M): 607.92
# =========================================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 196.54
# Params size (MB): 3.84
# Estimated Total Size (MB): 200.43
# =========================================================================================================

# %% [markdown]
# ## Utility Function for WAV -> MelSpectrogram

# %%
def waveform_to_logmel(
    waveform: torch.Tensor,
    sample_rate: int = 16000,
    n_fft: int = 512,
    hop_length: int = 160,
    n_mels: int = 60,       ## 72 for vox2 ;  60 for B0
    f_min: float = 20.0,
    f_max: float = 8000.0,
    preemphasis_alpha: float = 0.97
):
    """
    Reproduces the main logic of 'NormalizeAudio', 'PreEmphasis',
    and 'MelSpectrogram' from the 'MelBanks' layer.
    """

    # 1) NormalizeAudio
    waveform = waveform / (waveform.abs().max() + 1e-8)

    # 2) PreEmphasis
    shifted = torch.roll(waveform, shifts=1, dims=1)
    waveform_preemph = waveform - preemphasis_alpha * shifted
    # fix first sample
    waveform_preemph[:, 0] = waveform[:, 0]

    # 3) MelSpectrogram
    mel_transform = torchaudio.transforms.MelSpectrogram(
        sample_rate=sample_rate,
        n_fft=n_fft,
        hop_length=hop_length,
        n_mels=n_mels,
        f_min=f_min,
        f_max=f_max,
        power=2.0,
        center=False
    )
    mel_spec = mel_transform(waveform_preemph)  # shape: [channel=1, n_mels, time_frames]

    # Log scale
    log_mel = torch.log(mel_spec + 1e-6)
    return log_mel  # shape: [1, n_mels, time_frames]

# %%
def example_inference(wav_path: str):
    # (a) Load audio
    waveform, sr = torchaudio.load(wav_path)  # shape: [channels, time]
    # If stereo, select one channel, or average:
    if waveform.shape[0] > 1:
        waveform = waveform.mean(dim=0, keepdim=True)

    # (b) Convert to log-mel
    log_mel = waveform_to_logmel(waveform, sample_rate=sr)
    # Now log_mel shape is [1, n_mels, time_frames].

    # (c) Model expects a batch, so add batch dim => [B=1, 1, n_mels, time_frames]
    log_mel = log_mel.unsqueeze(0)

    # (d) Forward pass
    with torch.no_grad():
        embedding = model_no_mel(log_mel)  # shape typically [1, 192] or so

    print("Embedding shape:", embedding.shape)
    #print("Embedding:", embedding)
    return embedding

# %%
# Compute similarity between two embeddings
def cosine_similarity(embedding1, embedding2):
    return F.cosine_similarity(embedding1, embedding2).item()

def cosine_similarity_numpys(emb1: np.ndarray, emb2: np.ndarray) -> float:
    """
    Compute cosine similarity between two vectors of shape (D,) or (1, D).
    """
    # If shape is (1, D), flatten to (D,)
    v1 = emb1.flatten()
    v2 = emb2.flatten()

    # dot product
    dot = np.dot(v1, v2)
    # norms
    norm1 = np.linalg.norm(v1)
    norm2 = np.linalg.norm(v2)

    # Add a small epsilon in case of very small norms
    sim = dot / (norm1 * norm2 + 1e-8)
    return sim

# %%
embed1 = example_inference("testRob1.wav")
embed2 = example_inference("testRob2.wav")
embed3 = example_inference("testme1.wav")
embed4 = example_inference("testme2.wav")
# Out:
# Backbone output shape: torch.Size([1, 600, 219])
# Embedding shape: torch.Size([1, 192])
# Backbone output shape: torch.Size([1, 600, 200])
# Embedding shape: torch.Size([1, 192])
# /data/proj/voice/pyvoice_venv/lib/python3.10/site-packages/torchaudio/functional/functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (60) may be set too high. Or, the value for `n_freqs` (257) may be set too low.
#   warnings.warn(
# Backbone output shape: torch.Size([1, 600, 525])
# Embedding shape: torch.Size([1, 192])
# Backbone output shape: torch.Size([1, 600, 993])
# Embedding shape: torch.Size([1, 192])

# %%
print(f"Similarity (robot to robot): {cosine_similarity_numpys(embed1, embed2)}")
print(f"Similarity (robot to me   ): {cosine_similarity_numpys(embed1, embed3)}")
print(f"Similarity (me 1 to me 2  ): {cosine_similarity_numpys(embed3, embed4)}")
# Out:
# Similarity (robot to robot): 0.9962206482887268
# Similarity (robot to me   ): 0.9731134176254272
# Similarity (me 1 to me 2  ): 0.9976266026496887
# /tmp/ipykernel_2216155/3060022475.py:14: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   dot = np.dot(v1, v2)

# %% [markdown]
# ## store

# %%
import onnx

def export_to_onnx(model, onnx_path="ReDimNet_no_mel.onnx"):
    model.eval()
    
    # Create a dummy input with shape matching [B=1, 1, n_mels=72, time_frames=200] (example)
    dummy_input = torch.randn(1, 1, 60, 200)
    
    #  fixed-length segments 
    torch.onnx.export(
        model_no_mel,
        dummy_input,
        onnx_path,
        input_names=["log_mel"],
        output_names=["embedding"],
        opset_version=11
    )
    print("Exported to", onnx_path)
    
    # ## Export with Dynamic Axis
    # torch.onnx.export(
    #     model_no_mel,                 
    #     dummy_input,                 
    #     onnx_path,
    #     input_names=["log_mel"],
    #     output_names=["embedding"],
    #     opset_version=19,
    #     dynamic_axes={
    #         "log_mel": {0: "batch_size", 3: "time_frames"},
    #         "embedding": {0: "batch_size"}
    #     }
    # )
    # print("Exported to", onnx_path)

# Example usage
export_to_onnx(model_no_mel)
# Out:
# /tmp/ipykernel_2216155/713669357.py:43: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   pad_total = max((L_in - 1) * self.s + (self.k - 1) * self.d + 1 - L_in, 0)
# Backbone output shape: torch.Size([1, 600, 200])
# /data/proj/voice/pyvoice_venv/lib/python3.10/site-packages/torch/onnx/utils.py:657: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /pytorch/torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /data/proj/voice/pyvoice_venv/lib/python3.10/site-packages/torch/onnx/utils.py:1127: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /pytorch/torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# Exported to ReDimNet_no_mel.onnx

# %%
# !ls -lah ReDimNet_no_mel.onnx
# Out:
# -rw-rw-r-- 1 vlad vlad 4.1M Jun 11 08:28 ReDimNet_no_mel.onnx

# %% [markdown]
# ## verify

# %%
import onnx
onnx_model = onnx.load("ReDimNet_no_mel.onnx")
onnx.checker.check_model(onnx_model)
print("ONNX model is valid!")
# Out:
# ONNX model is valid!

# %%
print(type(model_no_mel))
print(isinstance(model_no_mel, nn.Module))
# Out:
# <class '__main__.ReDimNetNoMel'>
# True

# %%
type(onnx_model)
# Out:
# onnx.onnx_ml_pb2.ModelProto

# %%
def pad_or_crop_logmel(log_mel, target_frames=200):
    """
    Ensures log_mel is shaped [1, n_mels, target_frames] by:
    - Padding with zeros on the right if too short
    - Center-cropping if too long
    """
    B, M, T = log_mel.shape
    if T < target_frames:
        pad_amt = target_frames - T
        log_mel = F.pad(log_mel, (0, pad_amt))  # pad at end
        print(f"Padding log_mel from {T} to {target_frames} frames")
    elif T > target_frames:
        start = (T - target_frames) // 2
        log_mel = log_mel[:, :, start:start + target_frames]
        print(f"Cropping log_mel from {T} to {target_frames} frames")
    return log_mel


def waveform_to_logmel(
    waveform: torch.Tensor,
    sample_rate=16000,
    n_fft=512,
    hop_length=160,
    n_mels=60,         # match whatever your model expects
    f_min=20.0,
    f_max=8000.0,
    preemphasis_alpha=0.97,
    target_frames=200
):
    """
    Converts waveform -> normalized, preemphasized -> log-mel spectrogram
    Returns shape: [1, 1, n_mels, target_frames]
    """
    # 1) Normalize
    waveform = waveform / (waveform.abs().max() + 1e-8)
    # 2) PreEmphasis
    shifted = torch.roll(waveform, shifts=1, dims=1)
    waveform_preemph = waveform - preemphasis_alpha * shifted
    waveform_preemph[:, 0] = waveform[:, 0]
    # 3) MelSpectrogram
    mel_transform = torchaudio.transforms.MelSpectrogram(
        sample_rate=sample_rate,
        n_fft=n_fft,
        hop_length=hop_length,
        n_mels=n_mels,
        f_min=f_min,
        f_max=f_max,
        power=2.0,
        center=False
    )
    mel_spec = mel_transform(waveform_preemph)
    # 4) Log scale
    log_mel = torch.log(mel_spec + 1e-6)
    
    # 5) Pad/crop to fixed number of frames
    log_mel = pad_or_crop_logmel(log_mel, target_frames=target_frames)

    print("Log-mel shape:", log_mel.shape)  # Expect [1, 1, 60, 200]
    return log_mel

# %%
import onnxruntime as ort

def run_inference_onnx(onnx_path, wav_path):
    """
    Loads an audio file, converts to log-mel, and runs inference
    in an ONNX session. Returns the embedding as a NumPy array.
    """
    #######################################
    # 1) Load your ONNX model
    #######################################
    # (Optional) onnx.checker to confirm it’s valid
    onnx_model = onnx.load(onnx_path)
    onnx.checker.check_model(onnx_model)
    print(f"Loaded and checked ONNX model from: {onnx_path}")

    # Create an inference session
    session = ort.InferenceSession(onnx_path)

    # Usually we retrieve the first input & output name
    input_name = session.get_inputs()[0].name
    output_name = session.get_outputs()[0].name

    #######################################
    # 2) Load audio, get log-mel
    #######################################
    waveform, sr = torchaudio.load(wav_path)
    # If multi-channel, downmix:
    if waveform.shape[0] > 1:
        waveform = waveform.mean(dim=0, keepdim=True)

    log_mel = waveform_to_logmel(waveform, sample_rate=sr)
    # Insert a batch dimension => shape [B, 1, n_mels, frames]
    log_mel = log_mel.unsqueeze(0)  # => [1, 1, n_mels, time_frames]

    #######################################
    # 3) ONNX Inference
    #######################################
    # Convert to NumPy for ONNX runtime
    log_mel_np = log_mel.cpu().numpy()
    # Run inference
    outputs = session.run([output_name], {input_name: log_mel_np})
    # outputs is a list; typically we want the first item
    embedding = outputs[0]  # shape is [1, embedding_dim]

    print("Embedding shape:", embedding.shape)
    # print("Embedding data:\n", embedding)
    return embedding

# %%
onnx_model_path = "ReDimNet_no_mel.onnx"

embed1 = run_inference_onnx(onnx_model_path, "testRob1.wav")
embed2 = run_inference_onnx(onnx_model_path, "testRob2.wav")
embed3 = run_inference_onnx(onnx_model_path, "testme1.wav")
embed4 = run_inference_onnx(onnx_model_path, "testme2.wav")
# Out:
# Loaded and checked ONNX model from: ReDimNet_no_mel.onnx
# Cropping log_mel from 219 to 200 frames
# Log-mel shape: torch.Size([1, 60, 200])
# Embedding shape: (1, 192)
# Loaded and checked ONNX model from: ReDimNet_no_mel.onnx
# Log-mel shape: torch.Size([1, 60, 200])
# Embedding shape: (1, 192)
# Loaded and checked ONNX model from: ReDimNet_no_mel.onnx
# Cropping log_mel from 525 to 200 frames
# Log-mel shape: torch.Size([1, 60, 200])
# Embedding shape: (1, 192)
# Loaded and checked ONNX model from: ReDimNet_no_mel.onnx
# Cropping log_mel from 993 to 200 frames
# Log-mel shape: torch.Size([1, 60, 200])
# Embedding shape: (1, 192)

# %%
print(f"Similarity (robot to robot): {cosine_similarity_numpys(embed1, embed2)}")
print(f"Similarity (robot to me   ): {cosine_similarity_numpys(embed1, embed3)}")
print(f"Similarity (me 1 to me 2  ): {cosine_similarity_numpys(embed3, embed4)}")
# Out:
# Similarity (robot to robot): 0.995625376701355
# Similarity (robot to me   ): 0.9599852561950684
# Similarity (me 1 to me 2  ): 0.9903588891029358

# %% [markdown]
# ## cal fake data

# %% [markdown]
# * run in rknn docker:
#
# ``` bash
#
# import os
# import numpy as np
# import torch
#
# # Directory for calibration inputs
# os.makedirs("calib_npy", exist_ok=True)
#
# # Create 100 dummy log-mel tensors
# for i in range(10):
#     log_mel = torch.randn(1, 1, 60, 200).numpy().astype(np.float32)
#     np.save(f"calib_npy/sample_{i}.npy", log_mel)
#
# # Write dataset.txt listing all paths
# with open("dataset.txt", "w") as f:
#     for i in range(10):
#         f.write(f"calib_npy/sample_{i}.npy\n")
#
#
# ````

# %% [markdown]
# ## converts
#
# * python convert.py ReDimNet_no_mel.onnx  rk3588 fp ReDimNet_no_mel.rknn
# * python convert.py ReDimNet_no_mel.onnx  rv1106 i8  ReDimNet_no_mel.rknn
