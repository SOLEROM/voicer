# %% [markdown]
# # qunat?

# %%
from onnx import numpy_helper

onnx_model = onnx.load(onnx_model_path)
graph = onnx_model.graph

print("Model Initializers (Weights) Info:")
total_params = 0
for initializer in graph.initializer:
    arr = numpy_helper.to_array(initializer)
    print(f"  Name: {initializer.name}")
    print(f"    ONNX data_type: {initializer.data_type} (see onnx.TensorProto for meaning)")
    print(f"    Shape: {arr.shape}")
    print(f"    Num parameters: {arr.size}")
    print(f"    Dtype in numpy: {arr.dtype}\n")
    total_params += arr.size

print(f"Total number of parameters in the model: {total_params}\n")
# Out:
# Model Initializers (Weights) Info:
#   Name: backbone.stem.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 1, 3, 3)
#     Num parameters: 90
#     Dtype in numpy: float32
#
#   Name: backbone.stem.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 10, 1, 1)
#     Num parameters: 100
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.2.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.3.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 1, 3, 3)
#     Num parameters: 90
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.3.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 10, 1, 1)
#     Num parameters: 100
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.3.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.3.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.3.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.3.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.3.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.3.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 1, 3, 3)
#     Num parameters: 90
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.4.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 1, 3, 3)
#     Num parameters: 90
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.4.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 10, 1, 1)
#     Num parameters: 100
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.4.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.4.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.4.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.4.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.4.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.4.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 1, 3, 3)
#     Num parameters: 90
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.red_dim_conv.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 600, 1)
#     Num parameters: 12000
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.red_dim_conv.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.0.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 7)
#     Num parameters: 140
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.0.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.0.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.0.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.0.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.0.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.0.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.0.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.1.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 19)
#     Num parameters: 380
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.1.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.1.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.1.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.1.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.1.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.1.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.1.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.2.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 31)
#     Num parameters: 620
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.2.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.2.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.2.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.2.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.2.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.2.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.2.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.3.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 59)
#     Num parameters: 1180
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.3.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.3.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.3.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.3.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.3.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.3.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.3.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.4.attention.k_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.4.attention.v_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.4.attention.q_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.4.attention.out_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.4.layer_norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.4.layer_norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.4.feed_forward.intermediate_dense.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.4.feed_forward.output_dense.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.4.final_layer_norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.tcm.4.final_layer_norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.exp_dim_conv.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (600, 20, 1)
#     Num parameters: 12000
#     Dtype in numpy: float32
#
#   Name: backbone.stage0.6.exp_dim_conv.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (600,)
#     Num parameters: 600
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 10, 2, 1)
#     Num parameters: 800
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.2.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.3.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 1, 3, 3)
#     Num parameters: 360
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.3.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 40, 1, 1)
#     Num parameters: 1600
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.3.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.3.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.3.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.3.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.3.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.3.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 1, 3, 3)
#     Num parameters: 360
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.4.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 1, 3, 3)
#     Num parameters: 360
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.4.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 40, 1, 1)
#     Num parameters: 1600
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.4.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.4.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.4.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.4.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.4.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.4.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 1, 3, 3)
#     Num parameters: 360
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.5.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 1, 3, 3)
#     Num parameters: 360
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.5.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 40, 1, 1)
#     Num parameters: 1600
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.5.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.5.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.5.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.5.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.5.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.5.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 1, 3, 3)
#     Num parameters: 360
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.6.3.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.6.3.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.red_dim_conv.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 600, 1)
#     Num parameters: 12000
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.red_dim_conv.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.0.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 7)
#     Num parameters: 140
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.0.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.0.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.0.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.0.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.0.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.0.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.0.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.1.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 19)
#     Num parameters: 380
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.1.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.1.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.1.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.1.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.1.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.1.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.1.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.2.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 31)
#     Num parameters: 620
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.2.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.2.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.2.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.2.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.2.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.2.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.2.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.3.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 59)
#     Num parameters: 1180
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.3.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.3.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.3.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.3.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.3.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.3.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.3.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.4.attention.k_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.4.attention.v_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.4.attention.q_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.4.attention.out_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.4.layer_norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.4.layer_norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.4.feed_forward.intermediate_dense.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.4.feed_forward.output_dense.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.4.final_layer_norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.tcm.4.final_layer_norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.exp_dim_conv.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (600, 20, 1)
#     Num parameters: 12000
#     Dtype in numpy: float32
#
#   Name: backbone.stage1.8.exp_dim_conv.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (600,)
#     Num parameters: 600
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 20, 1, 1)
#     Num parameters: 1200
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.2.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.3.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1, 3, 3)
#     Num parameters: 540
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.3.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60, 1, 1)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.3.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.3.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.3.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.3.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.3.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.3.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1, 3, 3)
#     Num parameters: 540
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.4.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1, 3, 3)
#     Num parameters: 540
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.4.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60, 1, 1)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.4.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.4.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.4.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.4.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.4.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.4.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1, 3, 3)
#     Num parameters: 540
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.5.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1, 3, 3)
#     Num parameters: 540
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.5.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60, 1, 1)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.5.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.5.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.5.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.5.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.5.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.5.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1, 3, 3)
#     Num parameters: 540
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.6.3.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.6.3.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.red_dim_conv.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 600, 1)
#     Num parameters: 12000
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.red_dim_conv.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.0.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 7)
#     Num parameters: 140
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.0.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.0.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.0.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.0.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.0.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.0.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.0.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.1.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 19)
#     Num parameters: 380
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.1.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.1.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.1.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.1.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.1.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.1.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.1.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.2.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 31)
#     Num parameters: 620
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.2.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.2.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.2.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.2.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.2.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.2.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.2.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.3.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1, 59)
#     Num parameters: 1180
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.3.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.3.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.3.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.3.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.3.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.3.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20, 1)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.3.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.4.attention.k_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.4.attention.v_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.4.attention.q_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.4.attention.out_proj.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.4.layer_norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.4.layer_norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.4.feed_forward.intermediate_dense.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.4.feed_forward.output_dense.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.4.final_layer_norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.tcm.4.final_layer_norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.exp_dim_conv.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (600, 20, 1)
#     Num parameters: 12000
#     Dtype in numpy: float32
#
#   Name: backbone.stage2.8.exp_dim_conv.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (600,)
#     Num parameters: 600
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 20, 2, 1)
#     Num parameters: 3200
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.2.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.3.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 1, 3, 3)
#     Num parameters: 720
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.3.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 80, 1, 1)
#     Num parameters: 6400
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.3.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.3.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.3.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.3.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.3.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.3.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 1, 3, 3)
#     Num parameters: 720
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.4.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 1, 3, 3)
#     Num parameters: 720
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.4.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 80, 1, 1)
#     Num parameters: 6400
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.4.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.4.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.4.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.4.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.4.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.4.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 1, 3, 3)
#     Num parameters: 720
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.5.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 1, 3, 3)
#     Num parameters: 720
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.5.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 80, 1, 1)
#     Num parameters: 6400
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.5.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.5.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.5.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.5.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.5.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.5.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 1, 3, 3)
#     Num parameters: 720
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.6.conv_block.conv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 1, 3, 3)
#     Num parameters: 720
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.6.conv_block.conv1pw.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 80, 1, 1)
#     Num parameters: 6400
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.6.conv_block.conv1pw.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.6.conv_block.bn1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.6.conv_block.bn1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.6.conv_block.bn1.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.6.conv_block.bn1.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.6.conv_block.conv2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 1, 3, 3)
#     Num parameters: 720
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.7.3.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 40, 1, 1)
#     Num parameters: 1600
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.7.3.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.red_dim_conv.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 600, 1)
#     Num parameters: 36000
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.red_dim_conv.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.0.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1, 7)
#     Num parameters: 420
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.0.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.0.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.0.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.0.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.0.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.0.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60, 1)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.0.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.1.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1, 19)
#     Num parameters: 1140
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.1.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.1.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.1.norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.1.norm.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.1.norm.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.1.pwconv1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60, 1)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.1.pwconv1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.2.dwconvs.0.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1, 31)
#     Num parameters: 1860
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.2.dwconvs.0.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.2.norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage3.9.tcm.2.norm.bias
# ...
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage4.7.tcm.4.layer_norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage4.7.tcm.4.feed_forward.intermediate_dense.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage4.7.tcm.4.feed_forward.output_dense.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage4.7.tcm.4.final_layer_norm.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage4.7.tcm.4.final_layer_norm.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: backbone.stage4.7.exp_dim_conv.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (600, 60, 1)
#     Num parameters: 36000
#     Dtype in numpy: float32
#
#   Name: backbone.stage4.7.exp_dim_conv.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (600,)
#     Num parameters: 600
#     Dtype in numpy: float32
#
#   Name: pool.linear1.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (128, 1800, 1)
#     Num parameters: 230400
#     Dtype in numpy: float32
#
#   Name: pool.linear1.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (128,)
#     Num parameters: 128
#     Dtype in numpy: float32
#
#   Name: pool.linear2.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (600, 128, 1)
#     Num parameters: 76800
#     Dtype in numpy: float32
#
#   Name: pool.linear2.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (600,)
#     Num parameters: 600
#     Dtype in numpy: float32
#
#   Name: bn.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (1200,)
#     Num parameters: 1200
#     Dtype in numpy: float32
#
#   Name: bn.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (1200,)
#     Num parameters: 1200
#     Dtype in numpy: float32
#
#   Name: bn.running_mean
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (1200,)
#     Num parameters: 1200
#     Dtype in numpy: float32
#
#   Name: bn.running_var
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (1200,)
#     Num parameters: 1200
#     Dtype in numpy: float32
#
#   Name: linear.weight
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (192, 1200)
#     Num parameters: 230400
#     Dtype in numpy: float32
#
#   Name: linear.bias
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (192,)
#     Num parameters: 192
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_1989
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 10, 1, 1)
#     Num parameters: 100
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_1990
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_1992
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 10, 1, 1)
#     Num parameters: 100
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_1993
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10,)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_1995
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 40, 1, 1)
#     Num parameters: 1600
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_1996
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_1998
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 40, 1, 1)
#     Num parameters: 1600
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_1999
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2001
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 40, 1, 1)
#     Num parameters: 1600
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2002
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2004
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 2, 3, 3)
#     Num parameters: 360
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2005
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2007
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60, 1, 1)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2008
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2010
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60, 1, 1)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2011
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2013
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60, 1, 1)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2014
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60,)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2016
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 3, 3, 3)
#     Num parameters: 540
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2017
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20,)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2019
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 80, 1, 1)
#     Num parameters: 6400
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2020
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2022
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 80, 1, 1)
#     Num parameters: 6400
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2023
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2025
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 80, 1, 1)
#     Num parameters: 6400
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2026
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2028
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80, 80, 1, 1)
#     Num parameters: 6400
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2029
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (80,)
#     Num parameters: 80
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2031
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 2, 3, 3)
#     Num parameters: 720
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2032
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2034
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 40, 1, 1)
#     Num parameters: 1600
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2035
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2037
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 40, 1, 1)
#     Num parameters: 1600
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2038
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2040
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40, 40, 1, 1)
#     Num parameters: 1600
#     Dtype in numpy: float32
#
#   Name: onnx::Conv_2041
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (40,)
#     Num parameters: 40
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2045
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 1, 1)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: onnx::Add_2046
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (10, 1, 1)
#     Num parameters: 10
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2049
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (1, 1, 1, 1)
#     Num parameters: 1
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2053
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: onnx::Add_2054
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2055
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2056
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2063
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2075
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2076
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2077
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2080
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (1, 2, 600, 1)
#     Num parameters: 1200
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2084
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: onnx::Add_2085
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2086
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2087
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2094
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2106
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2107
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2108
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2111
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (1, 3, 600, 1)
#     Num parameters: 1800
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2115
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: onnx::Add_2116
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 1)
#     Num parameters: 20
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2117
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2118
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2125
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2137
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2138
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2139
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (20, 20)
#     Num parameters: 400
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2142
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (1, 4, 600, 1)
#     Num parameters: 2400
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2146
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: onnx::Add_2147
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2148
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2149
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2156
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2168
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2169
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2170
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2173
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (1, 5, 600, 1)
#     Num parameters: 3000
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2177
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: onnx::Add_2178
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 1)
#     Num parameters: 60
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2179
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2180
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2187
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2199
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2200
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::MatMul_2201
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (60, 60)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
#   Name: onnx::Mul_2204
#     ONNX data_type: 1 (see onnx.TensorProto for meaning)
#     Shape: (1, 6, 600, 1)
#     Num parameters: 3600
#     Dtype in numpy: float32
#
# Total number of parameters in the model: 1007931

# %%
# Check for quantization ops in the graph
# A very rough indicator of whether the model is using ONNX-quantized operators is if it has
# QuantizeLinear or DequantizeLinear ops in the graph. (There are other ways to check for
# custom quantization, but this is a good start.)
quant_ops = {"QuantizeLinear", "DequantizeLinear"}
found_quant_nodes = any(node.op_type in quant_ops for node in graph.node)

if found_quant_nodes:
    print("This model has quantization nodes (QuantizeLinear/DequantizeLinear).")
else:
    print("No quantization nodes detected. It may still be floating-point or use another quant scheme.")
# Out:
# No quantization nodes detected. It may still be floating-point or use another quant scheme.

# %% [markdown]
# quantization approaches in ONNX Runtime:
#
#     Dynamic Quantization (quantize_dynamic)
#         Quickest and easiest.
#         Quantizes only the weights by default. Activations are still in float32.
#         Can help reduce model size and possibly speed up inference on some targets.
#
#     Static Post-Training Quantization (quantize_static)
#         More advanced.
#         Requires calibration data (representative input examples).
#         Quantizes weights and activations to int8.
#         Tends to yield better speedups or smaller models for hardware that supports int8.
#
#     Quantization-Aware Training (quantize_qat)
#         Performed during training.
#         You must have trained the model in a QAT-friendly framework.
#         Produces the best accuracy for int8.

# %% [markdown]
# ## Dynamic Quantization Example

# %%
from onnxruntime.quantization import QuantType, quantize_dynamic

input_model_path = "ReDimNet_no_mel.onnx"
output_model_path = "ReDimNet_no_mel_int8.onnx"

# QuantType.QInt8 -> quantize weights to int8
quantize_dynamic(
    model_input=input_model_path,
    model_output=output_model_path,
    weight_type=QuantType.QInt8,  # or QuantType.QUInt8
)
# Out:
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md

# %%
# !ls -lha ReDimNet_no_mel_int8.onnx
# Out:
# -rw-rw-r-- 1 vlad vlad 1.8M Mar  8 11:30 ReDimNet_no_mel_int8.onnx

# %%
onnx_model = onnx.load(output_model_path)
graph = onnx_model.graph

print("After quantization:")
for initializer in graph.initializer:
    print(f"  {initializer.name} -> data_type: {initializer.data_type}")
# Out:
# After quantization:
#   backbone.stem.0.bias -> data_type: 1
#   backbone.stage0.2.bias -> data_type: 1
#   backbone.stage0.3.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage0.3.conv_block.bn1.weight -> data_type: 1
#   backbone.stage0.3.conv_block.bn1.bias -> data_type: 1
#   backbone.stage0.3.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage0.3.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage0.4.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage0.4.conv_block.bn1.weight -> data_type: 1
#   backbone.stage0.4.conv_block.bn1.bias -> data_type: 1
#   backbone.stage0.4.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage0.4.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage0.6.red_dim_conv.0.bias -> data_type: 1
#   backbone.stage0.6.tcm.0.dwconvs.0.bias -> data_type: 1
#   backbone.stage0.6.tcm.0.norm.weight -> data_type: 1
#   backbone.stage0.6.tcm.0.norm.bias -> data_type: 1
#   backbone.stage0.6.tcm.0.norm.running_mean -> data_type: 1
#   backbone.stage0.6.tcm.0.norm.running_var -> data_type: 1
#   backbone.stage0.6.tcm.0.pwconv1.bias -> data_type: 1
#   backbone.stage0.6.tcm.1.dwconvs.0.bias -> data_type: 1
#   backbone.stage0.6.tcm.1.norm.weight -> data_type: 1
#   backbone.stage0.6.tcm.1.norm.bias -> data_type: 1
#   backbone.stage0.6.tcm.1.norm.running_mean -> data_type: 1
#   backbone.stage0.6.tcm.1.norm.running_var -> data_type: 1
#   backbone.stage0.6.tcm.1.pwconv1.bias -> data_type: 1
#   backbone.stage0.6.tcm.2.dwconvs.0.bias -> data_type: 1
#   backbone.stage0.6.tcm.2.norm.weight -> data_type: 1
#   backbone.stage0.6.tcm.2.norm.bias -> data_type: 1
#   backbone.stage0.6.tcm.2.norm.running_mean -> data_type: 1
#   backbone.stage0.6.tcm.2.norm.running_var -> data_type: 1
#   backbone.stage0.6.tcm.2.pwconv1.bias -> data_type: 1
#   backbone.stage0.6.tcm.3.dwconvs.0.bias -> data_type: 1
#   backbone.stage0.6.tcm.3.norm.weight -> data_type: 1
#   backbone.stage0.6.tcm.3.norm.bias -> data_type: 1
#   backbone.stage0.6.tcm.3.norm.running_mean -> data_type: 1
#   backbone.stage0.6.tcm.3.norm.running_var -> data_type: 1
#   backbone.stage0.6.tcm.3.pwconv1.bias -> data_type: 1
#   backbone.stage0.6.tcm.4.attention.k_proj.bias -> data_type: 1
#   backbone.stage0.6.tcm.4.attention.v_proj.bias -> data_type: 1
#   backbone.stage0.6.tcm.4.attention.q_proj.bias -> data_type: 1
#   backbone.stage0.6.tcm.4.attention.out_proj.bias -> data_type: 1
#   backbone.stage0.6.tcm.4.layer_norm.weight -> data_type: 1
#   backbone.stage0.6.tcm.4.layer_norm.bias -> data_type: 1
#   backbone.stage0.6.tcm.4.feed_forward.intermediate_dense.bias -> data_type: 1
#   backbone.stage0.6.tcm.4.feed_forward.output_dense.bias -> data_type: 1
#   backbone.stage0.6.tcm.4.final_layer_norm.weight -> data_type: 1
#   backbone.stage0.6.tcm.4.final_layer_norm.bias -> data_type: 1
#   backbone.stage0.6.exp_dim_conv.bias -> data_type: 1
#   backbone.stage1.2.bias -> data_type: 1
#   backbone.stage1.3.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage1.3.conv_block.bn1.weight -> data_type: 1
#   backbone.stage1.3.conv_block.bn1.bias -> data_type: 1
#   backbone.stage1.3.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage1.3.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage1.4.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage1.4.conv_block.bn1.weight -> data_type: 1
#   backbone.stage1.4.conv_block.bn1.bias -> data_type: 1
#   backbone.stage1.4.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage1.4.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage1.5.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage1.5.conv_block.bn1.weight -> data_type: 1
#   backbone.stage1.5.conv_block.bn1.bias -> data_type: 1
#   backbone.stage1.5.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage1.5.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage1.6.3.bias -> data_type: 1
#   backbone.stage1.8.red_dim_conv.0.bias -> data_type: 1
#   backbone.stage1.8.tcm.0.dwconvs.0.bias -> data_type: 1
#   backbone.stage1.8.tcm.0.norm.weight -> data_type: 1
#   backbone.stage1.8.tcm.0.norm.bias -> data_type: 1
#   backbone.stage1.8.tcm.0.norm.running_mean -> data_type: 1
#   backbone.stage1.8.tcm.0.norm.running_var -> data_type: 1
#   backbone.stage1.8.tcm.0.pwconv1.bias -> data_type: 1
#   backbone.stage1.8.tcm.1.dwconvs.0.bias -> data_type: 1
#   backbone.stage1.8.tcm.1.norm.weight -> data_type: 1
#   backbone.stage1.8.tcm.1.norm.bias -> data_type: 1
#   backbone.stage1.8.tcm.1.norm.running_mean -> data_type: 1
#   backbone.stage1.8.tcm.1.norm.running_var -> data_type: 1
#   backbone.stage1.8.tcm.1.pwconv1.bias -> data_type: 1
#   backbone.stage1.8.tcm.2.dwconvs.0.bias -> data_type: 1
#   backbone.stage1.8.tcm.2.norm.weight -> data_type: 1
#   backbone.stage1.8.tcm.2.norm.bias -> data_type: 1
#   backbone.stage1.8.tcm.2.norm.running_mean -> data_type: 1
#   backbone.stage1.8.tcm.2.norm.running_var -> data_type: 1
#   backbone.stage1.8.tcm.2.pwconv1.bias -> data_type: 1
#   backbone.stage1.8.tcm.3.dwconvs.0.bias -> data_type: 1
#   backbone.stage1.8.tcm.3.norm.weight -> data_type: 1
#   backbone.stage1.8.tcm.3.norm.bias -> data_type: 1
#   backbone.stage1.8.tcm.3.norm.running_mean -> data_type: 1
#   backbone.stage1.8.tcm.3.norm.running_var -> data_type: 1
#   backbone.stage1.8.tcm.3.pwconv1.bias -> data_type: 1
#   backbone.stage1.8.tcm.4.attention.k_proj.bias -> data_type: 1
#   backbone.stage1.8.tcm.4.attention.v_proj.bias -> data_type: 1
#   backbone.stage1.8.tcm.4.attention.q_proj.bias -> data_type: 1
#   backbone.stage1.8.tcm.4.attention.out_proj.bias -> data_type: 1
#   backbone.stage1.8.tcm.4.layer_norm.weight -> data_type: 1
#   backbone.stage1.8.tcm.4.layer_norm.bias -> data_type: 1
#   backbone.stage1.8.tcm.4.feed_forward.intermediate_dense.bias -> data_type: 1
#   backbone.stage1.8.tcm.4.feed_forward.output_dense.bias -> data_type: 1
#   backbone.stage1.8.tcm.4.final_layer_norm.weight -> data_type: 1
#   backbone.stage1.8.tcm.4.final_layer_norm.bias -> data_type: 1
#   backbone.stage1.8.exp_dim_conv.bias -> data_type: 1
#   backbone.stage2.2.bias -> data_type: 1
#   backbone.stage2.3.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage2.3.conv_block.bn1.weight -> data_type: 1
#   backbone.stage2.3.conv_block.bn1.bias -> data_type: 1
#   backbone.stage2.3.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage2.3.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage2.4.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage2.4.conv_block.bn1.weight -> data_type: 1
#   backbone.stage2.4.conv_block.bn1.bias -> data_type: 1
#   backbone.stage2.4.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage2.4.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage2.5.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage2.5.conv_block.bn1.weight -> data_type: 1
#   backbone.stage2.5.conv_block.bn1.bias -> data_type: 1
#   backbone.stage2.5.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage2.5.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage2.6.3.bias -> data_type: 1
#   backbone.stage2.8.red_dim_conv.0.bias -> data_type: 1
#   backbone.stage2.8.tcm.0.dwconvs.0.bias -> data_type: 1
#   backbone.stage2.8.tcm.0.norm.weight -> data_type: 1
#   backbone.stage2.8.tcm.0.norm.bias -> data_type: 1
#   backbone.stage2.8.tcm.0.norm.running_mean -> data_type: 1
#   backbone.stage2.8.tcm.0.norm.running_var -> data_type: 1
#   backbone.stage2.8.tcm.0.pwconv1.bias -> data_type: 1
#   backbone.stage2.8.tcm.1.dwconvs.0.bias -> data_type: 1
#   backbone.stage2.8.tcm.1.norm.weight -> data_type: 1
#   backbone.stage2.8.tcm.1.norm.bias -> data_type: 1
#   backbone.stage2.8.tcm.1.norm.running_mean -> data_type: 1
#   backbone.stage2.8.tcm.1.norm.running_var -> data_type: 1
#   backbone.stage2.8.tcm.1.pwconv1.bias -> data_type: 1
#   backbone.stage2.8.tcm.2.dwconvs.0.bias -> data_type: 1
#   backbone.stage2.8.tcm.2.norm.weight -> data_type: 1
#   backbone.stage2.8.tcm.2.norm.bias -> data_type: 1
#   backbone.stage2.8.tcm.2.norm.running_mean -> data_type: 1
#   backbone.stage2.8.tcm.2.norm.running_var -> data_type: 1
#   backbone.stage2.8.tcm.2.pwconv1.bias -> data_type: 1
#   backbone.stage2.8.tcm.3.dwconvs.0.bias -> data_type: 1
#   backbone.stage2.8.tcm.3.norm.weight -> data_type: 1
#   backbone.stage2.8.tcm.3.norm.bias -> data_type: 1
#   backbone.stage2.8.tcm.3.norm.running_mean -> data_type: 1
#   backbone.stage2.8.tcm.3.norm.running_var -> data_type: 1
#   backbone.stage2.8.tcm.3.pwconv1.bias -> data_type: 1
#   backbone.stage2.8.tcm.4.attention.k_proj.bias -> data_type: 1
#   backbone.stage2.8.tcm.4.attention.v_proj.bias -> data_type: 1
#   backbone.stage2.8.tcm.4.attention.q_proj.bias -> data_type: 1
#   backbone.stage2.8.tcm.4.attention.out_proj.bias -> data_type: 1
#   backbone.stage2.8.tcm.4.layer_norm.weight -> data_type: 1
#   backbone.stage2.8.tcm.4.layer_norm.bias -> data_type: 1
#   backbone.stage2.8.tcm.4.feed_forward.intermediate_dense.bias -> data_type: 1
#   backbone.stage2.8.tcm.4.feed_forward.output_dense.bias -> data_type: 1
#   backbone.stage2.8.tcm.4.final_layer_norm.weight -> data_type: 1
#   backbone.stage2.8.tcm.4.final_layer_norm.bias -> data_type: 1
#   backbone.stage2.8.exp_dim_conv.bias -> data_type: 1
#   backbone.stage3.2.bias -> data_type: 1
#   backbone.stage3.3.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage3.3.conv_block.bn1.weight -> data_type: 1
#   backbone.stage3.3.conv_block.bn1.bias -> data_type: 1
#   backbone.stage3.3.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage3.3.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage3.4.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage3.4.conv_block.bn1.weight -> data_type: 1
#   backbone.stage3.4.conv_block.bn1.bias -> data_type: 1
#   backbone.stage3.4.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage3.4.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage3.5.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage3.5.conv_block.bn1.weight -> data_type: 1
#   backbone.stage3.5.conv_block.bn1.bias -> data_type: 1
#   backbone.stage3.5.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage3.5.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage3.6.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage3.6.conv_block.bn1.weight -> data_type: 1
#   backbone.stage3.6.conv_block.bn1.bias -> data_type: 1
#   backbone.stage3.6.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage3.6.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage3.7.3.bias -> data_type: 1
#   backbone.stage3.9.red_dim_conv.0.bias -> data_type: 1
#   backbone.stage3.9.tcm.0.dwconvs.0.bias -> data_type: 1
#   backbone.stage3.9.tcm.0.norm.weight -> data_type: 1
#   backbone.stage3.9.tcm.0.norm.bias -> data_type: 1
#   backbone.stage3.9.tcm.0.norm.running_mean -> data_type: 1
#   backbone.stage3.9.tcm.0.norm.running_var -> data_type: 1
#   backbone.stage3.9.tcm.0.pwconv1.bias -> data_type: 1
#   backbone.stage3.9.tcm.1.dwconvs.0.bias -> data_type: 1
#   backbone.stage3.9.tcm.1.norm.weight -> data_type: 1
#   backbone.stage3.9.tcm.1.norm.bias -> data_type: 1
#   backbone.stage3.9.tcm.1.norm.running_mean -> data_type: 1
#   backbone.stage3.9.tcm.1.norm.running_var -> data_type: 1
#   backbone.stage3.9.tcm.1.pwconv1.bias -> data_type: 1
#   backbone.stage3.9.tcm.2.dwconvs.0.bias -> data_type: 1
#   backbone.stage3.9.tcm.2.norm.weight -> data_type: 1
#   backbone.stage3.9.tcm.2.norm.bias -> data_type: 1
#   backbone.stage3.9.tcm.2.norm.running_mean -> data_type: 1
#   backbone.stage3.9.tcm.2.norm.running_var -> data_type: 1
#   backbone.stage3.9.tcm.2.pwconv1.bias -> data_type: 1
#   backbone.stage3.9.tcm.3.dwconvs.0.bias -> data_type: 1
#   backbone.stage3.9.tcm.3.norm.weight -> data_type: 1
#   backbone.stage3.9.tcm.3.norm.bias -> data_type: 1
#   backbone.stage3.9.tcm.3.norm.running_mean -> data_type: 1
#   backbone.stage3.9.tcm.3.norm.running_var -> data_type: 1
#   backbone.stage3.9.tcm.3.pwconv1.bias -> data_type: 1
#   backbone.stage3.9.tcm.4.attention.k_proj.bias -> data_type: 1
#   backbone.stage3.9.tcm.4.attention.v_proj.bias -> data_type: 1
#   backbone.stage3.9.tcm.4.attention.q_proj.bias -> data_type: 1
#   backbone.stage3.9.tcm.4.attention.out_proj.bias -> data_type: 1
#   backbone.stage3.9.tcm.4.layer_norm.weight -> data_type: 1
#   backbone.stage3.9.tcm.4.layer_norm.bias -> data_type: 1
#   backbone.stage3.9.tcm.4.feed_forward.intermediate_dense.bias -> data_type: 1
#   backbone.stage3.9.tcm.4.feed_forward.output_dense.bias -> data_type: 1
#   backbone.stage3.9.tcm.4.final_layer_norm.weight -> data_type: 1
#   backbone.stage3.9.tcm.4.final_layer_norm.bias -> data_type: 1
#   backbone.stage3.9.exp_dim_conv.bias -> data_type: 1
#   backbone.stage4.2.bias -> data_type: 1
#   backbone.stage4.3.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage4.3.conv_block.bn1.weight -> data_type: 1
#   backbone.stage4.3.conv_block.bn1.bias -> data_type: 1
#   backbone.stage4.3.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage4.3.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage4.4.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage4.4.conv_block.bn1.weight -> data_type: 1
#   backbone.stage4.4.conv_block.bn1.bias -> data_type: 1
#   backbone.stage4.4.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage4.4.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage4.5.conv_block.conv1pw.bias -> data_type: 1
#   backbone.stage4.5.conv_block.bn1.weight -> data_type: 1
#   backbone.stage4.5.conv_block.bn1.bias -> data_type: 1
#   backbone.stage4.5.conv_block.bn1.running_mean -> data_type: 1
#   backbone.stage4.5.conv_block.bn1.running_var -> data_type: 1
#   backbone.stage4.7.red_dim_conv.0.bias -> data_type: 1
#   backbone.stage4.7.tcm.0.dwconvs.0.bias -> data_type: 1
#   backbone.stage4.7.tcm.0.norm.weight -> data_type: 1
#   backbone.stage4.7.tcm.0.norm.bias -> data_type: 1
#   backbone.stage4.7.tcm.0.norm.running_mean -> data_type: 1
#   backbone.stage4.7.tcm.0.norm.running_var -> data_type: 1
#   backbone.stage4.7.tcm.0.pwconv1.bias -> data_type: 1
#   backbone.stage4.7.tcm.1.dwconvs.0.bias -> data_type: 1
#   backbone.stage4.7.tcm.1.norm.weight -> data_type: 1
#   backbone.stage4.7.tcm.1.norm.bias -> data_type: 1
#   backbone.stage4.7.tcm.1.norm.running_mean -> data_type: 1
#   backbone.stage4.7.tcm.1.norm.running_var -> data_type: 1
#   backbone.stage4.7.tcm.1.pwconv1.bias -> data_type: 1
#   backbone.stage4.7.tcm.2.dwconvs.0.bias -> data_type: 1
#   backbone.stage4.7.tcm.2.norm.weight -> data_type: 1
#   backbone.stage4.7.tcm.2.norm.bias -> data_type: 1
#   backbone.stage4.7.tcm.2.norm.running_mean -> data_type: 1
#   backbone.stage4.7.tcm.2.norm.running_var -> data_type: 1
#   backbone.stage4.7.tcm.2.pwconv1.bias -> data_type: 1
#   backbone.stage4.7.tcm.3.dwconvs.0.bias -> data_type: 1
#   backbone.stage4.7.tcm.3.norm.weight -> data_type: 1
#   backbone.stage4.7.tcm.3.norm.bias -> data_type: 1
#   backbone.stage4.7.tcm.3.norm.running_mean -> data_type: 1
#   backbone.stage4.7.tcm.3.norm.running_var -> data_type: 1
#   backbone.stage4.7.tcm.3.pwconv1.bias -> data_type: 1
#   backbone.stage4.7.tcm.4.attention.k_proj.bias -> data_type: 1
#   backbone.stage4.7.tcm.4.attention.v_proj.bias -> data_type: 1
#   backbone.stage4.7.tcm.4.attention.q_proj.bias -> data_type: 1
#   backbone.stage4.7.tcm.4.attention.out_proj.bias -> data_type: 1
#   backbone.stage4.7.tcm.4.layer_norm.weight -> data_type: 1
#   backbone.stage4.7.tcm.4.layer_norm.bias -> data_type: 1
#   backbone.stage4.7.tcm.4.feed_forward.intermediate_dense.bias -> data_type: 1
#   backbone.stage4.7.tcm.4.feed_forward.output_dense.bias -> data_type: 1
#   backbone.stage4.7.tcm.4.final_layer_norm.weight -> data_type: 1
#   backbone.stage4.7.tcm.4.final_layer_norm.bias -> data_type: 1
#   backbone.stage4.7.exp_dim_conv.bias -> data_type: 1
#   pool.linear1.bias -> data_type: 1
#   pool.linear2.bias -> data_type: 1
#   bn.weight -> data_type: 1
#   bn.bias -> data_type: 1
#   bn.running_mean -> data_type: 1
#   bn.running_var -> data_type: 1
#   linear.bias -> data_type: 1
#   onnx::Conv_1990 -> data_type: 1
#   onnx::Conv_1993 -> data_type: 1
#   onnx::Conv_1996 -> data_type: 1
#   onnx::Conv_1999 -> data_type: 1
#   onnx::Conv_2002 -> data_type: 1
#   onnx::Conv_2005 -> data_type: 1
#   onnx::Conv_2008 -> data_type: 1
#   onnx::Conv_2011 -> data_type: 1
#   onnx::Conv_2014 -> data_type: 1
#   onnx::Conv_2017 -> data_type: 1
#   onnx::Conv_2020 -> data_type: 1
#   onnx::Conv_2023 -> data_type: 1
#   onnx::Conv_2026 -> data_type: 1
#   onnx::Conv_2029 -> data_type: 1
#   onnx::Conv_2032 -> data_type: 1
#   onnx::Conv_2035 -> data_type: 1
#   onnx::Conv_2038 -> data_type: 1
#   onnx::Conv_2041 -> data_type: 1
#   onnx::Mul_2045 -> data_type: 1
#   onnx::Add_2046 -> data_type: 1
#   onnx::Mul_2049 -> data_type: 1
#   onnx::Mul_2053 -> data_type: 1
#   onnx::Add_2054 -> data_type: 1
#   onnx::Mul_2080 -> data_type: 1
#   onnx::Mul_2084 -> data_type: 1
#   onnx::Add_2085 -> data_type: 1
#   onnx::Mul_2111 -> data_type: 1
#   onnx::Mul_2115 -> data_type: 1
#   onnx::Add_2116 -> data_type: 1
#   onnx::Mul_2142 -> data_type: 1
#   onnx::Mul_2146 -> data_type: 1
#   onnx::Add_2147 -> data_type: 1
#   onnx::Mul_2173 -> data_type: 1
#   onnx::Mul_2177 -> data_type: 1
#   onnx::Add_2178 -> data_type: 1
#   onnx::Mul_2204 -> data_type: 1
#   backbone.stem.0.weight_scale -> data_type: 1
#   backbone.stem.0.weight_zero_point -> data_type: 3
#   backbone.stem.0.weight_quantized -> data_type: 3
#   /backbone/stem/stem.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.2.weight_scale -> data_type: 1
#   backbone.stage0.2.weight_zero_point -> data_type: 3
#   backbone.stage0.2.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.2/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.3.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage0.3.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage0.3.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage0.3.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage0.3.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage0.3.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.3/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.3.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage0.3.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage0.3.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_1989_scale -> data_type: 1
#   onnx::Conv_1989_zero_point -> data_type: 3
#   onnx::Conv_1989_quantized -> data_type: 3
#   /backbone/stage0/stage0.3/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.4.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage0.4.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage0.4.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage0.4.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage0.4.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage0.4.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.4/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.4.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage0.4.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage0.4.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_1992_scale -> data_type: 1
#   onnx::Conv_1992_zero_point -> data_type: 3
#   onnx::Conv_1992_quantized -> data_type: 3
#   /backbone/stage0/stage0.4/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.6.red_dim_conv.0.weight_scale -> data_type: 1
#   backbone.stage0.6.red_dim_conv.0.weight_zero_point -> data_type: 3
#   backbone.stage0.6.red_dim_conv.0.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.6/red_dim_conv/red_dim_conv.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.6.tcm.0.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage0.6.tcm.0.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage0.6.tcm.0.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.6/tcm/tcm.0/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.6.tcm.0.pwconv1.weight_scale -> data_type: 1
#   backbone.stage0.6.tcm.0.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage0.6.tcm.0.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.6/tcm/tcm.0/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.6.tcm.1.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage0.6.tcm.1.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage0.6.tcm.1.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.6/tcm/tcm.1/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.6.tcm.1.pwconv1.weight_scale -> data_type: 1
#   backbone.stage0.6.tcm.1.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage0.6.tcm.1.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.6/tcm/tcm.1/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.6.tcm.2.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage0.6.tcm.2.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage0.6.tcm.2.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.6/tcm/tcm.2/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.6.tcm.2.pwconv1.weight_scale -> data_type: 1
#   backbone.stage0.6.tcm.2.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage0.6.tcm.2.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.6/tcm/tcm.2/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.6.tcm.3.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage0.6.tcm.3.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage0.6.tcm.3.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.6/tcm/tcm.3/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage0.6.tcm.3.pwconv1.weight_scale -> data_type: 1
#   backbone.stage0.6.tcm.3.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage0.6.tcm.3.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.6/tcm/tcm.3/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   onnx::MatMul_2055_scale -> data_type: 1
#   onnx::MatMul_2055_zero_point -> data_type: 3
#   onnx::MatMul_2055_quantized -> data_type: 3
#   onnx::MatMul_2056_scale -> data_type: 1
#   onnx::MatMul_2056_zero_point -> data_type: 3
#   onnx::MatMul_2056_quantized -> data_type: 3
#   onnx::MatMul_2063_scale -> data_type: 1
#   onnx::MatMul_2063_zero_point -> data_type: 3
#   onnx::MatMul_2063_quantized -> data_type: 3
#   onnx::MatMul_2075_scale -> data_type: 1
#   onnx::MatMul_2075_zero_point -> data_type: 3
#   onnx::MatMul_2075_quantized -> data_type: 3
#   onnx::MatMul_2076_scale -> data_type: 1
#   onnx::MatMul_2076_zero_point -> data_type: 3
#   onnx::MatMul_2076_quantized -> data_type: 3
#   onnx::MatMul_2077_scale -> data_type: 1
#   onnx::MatMul_2077_zero_point -> data_type: 3
#   onnx::MatMul_2077_quantized -> data_type: 3
#   backbone.stage0.6.exp_dim_conv.weight_scale -> data_type: 1
#   backbone.stage0.6.exp_dim_conv.weight_zero_point -> data_type: 3
#   backbone.stage0.6.exp_dim_conv.weight_quantized -> data_type: 3
#   /backbone/stage0/stage0.6/exp_dim_conv/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.2.weight_scale -> data_type: 1
#   backbone.stage1.2.weight_zero_point -> data_type: 3
#   backbone.stage1.2.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.2/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.3.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage1.3.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage1.3.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage1.3.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage1.3.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage1.3.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.3/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.3.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage1.3.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage1.3.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_1995_scale -> data_type: 1
#   onnx::Conv_1995_zero_point -> data_type: 3
#   onnx::Conv_1995_quantized -> data_type: 3
#   /backbone/stage1/stage1.3/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.4.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage1.4.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage1.4.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage1.4.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage1.4.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage1.4.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.4/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.4.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage1.4.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage1.4.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_1998_scale -> data_type: 1
#   onnx::Conv_1998_zero_point -> data_type: 3
#   onnx::Conv_1998_quantized -> data_type: 3
#   /backbone/stage1/stage1.4/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.5.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage1.5.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage1.5.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage1.5.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage1.5.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage1.5.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.5/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.5.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage1.5.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage1.5.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2001_scale -> data_type: 1
#   onnx::Conv_2001_zero_point -> data_type: 3
#   onnx::Conv_2001_quantized -> data_type: 3
#   /backbone/stage1/stage1.5/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   onnx::Conv_2004_scale -> data_type: 1
#   onnx::Conv_2004_zero_point -> data_type: 3
#   onnx::Conv_2004_quantized -> data_type: 3
#   /backbone/stage1/stage1.6/stage1.6.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.6.3.weight_scale -> data_type: 1
#   backbone.stage1.6.3.weight_zero_point -> data_type: 3
#   backbone.stage1.6.3.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.6/stage1.6.3/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.8.red_dim_conv.0.weight_scale -> data_type: 1
#   backbone.stage1.8.red_dim_conv.0.weight_zero_point -> data_type: 3
#   backbone.stage1.8.red_dim_conv.0.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.8/red_dim_conv/red_dim_conv.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.8.tcm.0.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage1.8.tcm.0.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage1.8.tcm.0.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.8/tcm/tcm.0/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.8.tcm.0.pwconv1.weight_scale -> data_type: 1
#   backbone.stage1.8.tcm.0.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage1.8.tcm.0.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.8/tcm/tcm.0/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.8.tcm.1.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage1.8.tcm.1.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage1.8.tcm.1.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.8/tcm/tcm.1/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.8.tcm.1.pwconv1.weight_scale -> data_type: 1
#   backbone.stage1.8.tcm.1.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage1.8.tcm.1.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.8/tcm/tcm.1/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.8.tcm.2.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage1.8.tcm.2.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage1.8.tcm.2.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.8/tcm/tcm.2/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.8.tcm.2.pwconv1.weight_scale -> data_type: 1
#   backbone.stage1.8.tcm.2.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage1.8.tcm.2.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.8/tcm/tcm.2/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.8.tcm.3.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage1.8.tcm.3.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage1.8.tcm.3.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.8/tcm/tcm.3/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage1.8.tcm.3.pwconv1.weight_scale -> data_type: 1
#   backbone.stage1.8.tcm.3.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage1.8.tcm.3.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.8/tcm/tcm.3/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   onnx::MatMul_2086_scale -> data_type: 1
#   onnx::MatMul_2086_zero_point -> data_type: 3
#   onnx::MatMul_2086_quantized -> data_type: 3
#   onnx::MatMul_2087_scale -> data_type: 1
#   onnx::MatMul_2087_zero_point -> data_type: 3
#   onnx::MatMul_2087_quantized -> data_type: 3
#   onnx::MatMul_2094_scale -> data_type: 1
#   onnx::MatMul_2094_zero_point -> data_type: 3
#   onnx::MatMul_2094_quantized -> data_type: 3
#   onnx::MatMul_2106_scale -> data_type: 1
#   onnx::MatMul_2106_zero_point -> data_type: 3
#   onnx::MatMul_2106_quantized -> data_type: 3
#   onnx::MatMul_2107_scale -> data_type: 1
#   onnx::MatMul_2107_zero_point -> data_type: 3
#   onnx::MatMul_2107_quantized -> data_type: 3
#   onnx::MatMul_2108_scale -> data_type: 1
#   onnx::MatMul_2108_zero_point -> data_type: 3
#   onnx::MatMul_2108_quantized -> data_type: 3
#   backbone.stage1.8.exp_dim_conv.weight_scale -> data_type: 1
#   backbone.stage1.8.exp_dim_conv.weight_zero_point -> data_type: 3
#   backbone.stage1.8.exp_dim_conv.weight_quantized -> data_type: 3
#   /backbone/stage1/stage1.8/exp_dim_conv/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.2.weight_scale -> data_type: 1
#   backbone.stage2.2.weight_zero_point -> data_type: 3
#   backbone.stage2.2.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.2/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.3.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage2.3.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage2.3.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage2.3.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage2.3.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage2.3.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.3/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.3.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage2.3.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage2.3.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2007_scale -> data_type: 1
#   onnx::Conv_2007_zero_point -> data_type: 3
#   onnx::Conv_2007_quantized -> data_type: 3
#   /backbone/stage2/stage2.3/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.4.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage2.4.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage2.4.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage2.4.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage2.4.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage2.4.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.4/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.4.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage2.4.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage2.4.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2010_scale -> data_type: 1
#   onnx::Conv_2010_zero_point -> data_type: 3
#   onnx::Conv_2010_quantized -> data_type: 3
#   /backbone/stage2/stage2.4/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.5.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage2.5.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage2.5.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage2.5.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage2.5.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage2.5.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.5/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.5.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage2.5.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage2.5.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2013_scale -> data_type: 1
#   onnx::Conv_2013_zero_point -> data_type: 3
#   onnx::Conv_2013_quantized -> data_type: 3
#   /backbone/stage2/stage2.5/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   onnx::Conv_2016_scale -> data_type: 1
#   onnx::Conv_2016_zero_point -> data_type: 3
#   onnx::Conv_2016_quantized -> data_type: 3
#   /backbone/stage2/stage2.6/stage2.6.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.6.3.weight_scale -> data_type: 1
#   backbone.stage2.6.3.weight_zero_point -> data_type: 3
#   backbone.stage2.6.3.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.6/stage2.6.3/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.8.red_dim_conv.0.weight_scale -> data_type: 1
#   backbone.stage2.8.red_dim_conv.0.weight_zero_point -> data_type: 3
#   backbone.stage2.8.red_dim_conv.0.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.8/red_dim_conv/red_dim_conv.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.8.tcm.0.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage2.8.tcm.0.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage2.8.tcm.0.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.8/tcm/tcm.0/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.8.tcm.0.pwconv1.weight_scale -> data_type: 1
#   backbone.stage2.8.tcm.0.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage2.8.tcm.0.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.8/tcm/tcm.0/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.8.tcm.1.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage2.8.tcm.1.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage2.8.tcm.1.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.8/tcm/tcm.1/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.8.tcm.1.pwconv1.weight_scale -> data_type: 1
#   backbone.stage2.8.tcm.1.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage2.8.tcm.1.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.8/tcm/tcm.1/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.8.tcm.2.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage2.8.tcm.2.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage2.8.tcm.2.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.8/tcm/tcm.2/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.8.tcm.2.pwconv1.weight_scale -> data_type: 1
#   backbone.stage2.8.tcm.2.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage2.8.tcm.2.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.8/tcm/tcm.2/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.8.tcm.3.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage2.8.tcm.3.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage2.8.tcm.3.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.8/tcm/tcm.3/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage2.8.tcm.3.pwconv1.weight_scale -> data_type: 1
#   backbone.stage2.8.tcm.3.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage2.8.tcm.3.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.8/tcm/tcm.3/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   onnx::MatMul_2117_scale -> data_type: 1
#   onnx::MatMul_2117_zero_point -> data_type: 3
#   onnx::MatMul_2117_quantized -> data_type: 3
#   onnx::MatMul_2118_scale -> data_type: 1
#   onnx::MatMul_2118_zero_point -> data_type: 3
#   onnx::MatMul_2118_quantized -> data_type: 3
#   onnx::MatMul_2125_scale -> data_type: 1
#   onnx::MatMul_2125_zero_point -> data_type: 3
#   onnx::MatMul_2125_quantized -> data_type: 3
#   onnx::MatMul_2137_scale -> data_type: 1
#   onnx::MatMul_2137_zero_point -> data_type: 3
#   onnx::MatMul_2137_quantized -> data_type: 3
#   onnx::MatMul_2138_scale -> data_type: 1
#   onnx::MatMul_2138_zero_point -> data_type: 3
#   onnx::MatMul_2138_quantized -> data_type: 3
#   onnx::MatMul_2139_scale -> data_type: 1
#   onnx::MatMul_2139_zero_point -> data_type: 3
#   onnx::MatMul_2139_quantized -> data_type: 3
#   backbone.stage2.8.exp_dim_conv.weight_scale -> data_type: 1
#   backbone.stage2.8.exp_dim_conv.weight_zero_point -> data_type: 3
#   backbone.stage2.8.exp_dim_conv.weight_quantized -> data_type: 3
#   /backbone/stage2/stage2.8/exp_dim_conv/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.2.weight_scale -> data_type: 1
#   backbone.stage3.2.weight_zero_point -> data_type: 3
#   backbone.stage3.2.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.2/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.3.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage3.3.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage3.3.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage3.3.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage3.3.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage3.3.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.3/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.3.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage3.3.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage3.3.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2019_scale -> data_type: 1
#   onnx::Conv_2019_zero_point -> data_type: 3
#   onnx::Conv_2019_quantized -> data_type: 3
#   /backbone/stage3/stage3.3/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.4.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage3.4.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage3.4.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage3.4.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage3.4.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage3.4.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.4/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.4.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage3.4.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage3.4.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2022_scale -> data_type: 1
#   onnx::Conv_2022_zero_point -> data_type: 3
#   onnx::Conv_2022_quantized -> data_type: 3
#   /backbone/stage3/stage3.4/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.5.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage3.5.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage3.5.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage3.5.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage3.5.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage3.5.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.5/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.5.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage3.5.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage3.5.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2025_scale -> data_type: 1
#   onnx::Conv_2025_zero_point -> data_type: 3
#   onnx::Conv_2025_quantized -> data_type: 3
#   /backbone/stage3/stage3.5/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.6.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage3.6.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage3.6.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage3.6.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage3.6.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage3.6.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.6/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.6.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage3.6.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage3.6.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2028_scale -> data_type: 1
#   onnx::Conv_2028_zero_point -> data_type: 3
#   onnx::Conv_2028_quantized -> data_type: 3
#   /backbone/stage3/stage3.6/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   onnx::Conv_2031_scale -> data_type: 1
#   onnx::Conv_2031_zero_point -> data_type: 3
#   onnx::Conv_2031_quantized -> data_type: 3
#   /backbone/stage3/stage3.7/stage3.7.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.7.3.weight_scale -> data_type: 1
#   backbone.stage3.7.3.weight_zero_point -> data_type: 3
#   backbone.stage3.7.3.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.7/stage3.7.3/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.9.red_dim_conv.0.weight_scale -> data_type: 1
#   backbone.stage3.9.red_dim_conv.0.weight_zero_point -> data_type: 3
#   backbone.stage3.9.red_dim_conv.0.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.9/red_dim_conv/red_dim_conv.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.9.tcm.0.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage3.9.tcm.0.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage3.9.tcm.0.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.9/tcm/tcm.0/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.9.tcm.0.pwconv1.weight_scale -> data_type: 1
#   backbone.stage3.9.tcm.0.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage3.9.tcm.0.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.9/tcm/tcm.0/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.9.tcm.1.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage3.9.tcm.1.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage3.9.tcm.1.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.9/tcm/tcm.1/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.9.tcm.1.pwconv1.weight_scale -> data_type: 1
#   backbone.stage3.9.tcm.1.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage3.9.tcm.1.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.9/tcm/tcm.1/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.9.tcm.2.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage3.9.tcm.2.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage3.9.tcm.2.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.9/tcm/tcm.2/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.9.tcm.2.pwconv1.weight_scale -> data_type: 1
#   backbone.stage3.9.tcm.2.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage3.9.tcm.2.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.9/tcm/tcm.2/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.9.tcm.3.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage3.9.tcm.3.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage3.9.tcm.3.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.9/tcm/tcm.3/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage3.9.tcm.3.pwconv1.weight_scale -> data_type: 1
#   backbone.stage3.9.tcm.3.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage3.9.tcm.3.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.9/tcm/tcm.3/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   onnx::MatMul_2148_scale -> data_type: 1
#   onnx::MatMul_2148_zero_point -> data_type: 3
#   onnx::MatMul_2148_quantized -> data_type: 3
#   onnx::MatMul_2149_scale -> data_type: 1
#   onnx::MatMul_2149_zero_point -> data_type: 3
#   onnx::MatMul_2149_quantized -> data_type: 3
#   onnx::MatMul_2156_scale -> data_type: 1
#   onnx::MatMul_2156_zero_point -> data_type: 3
#   onnx::MatMul_2156_quantized -> data_type: 3
#   onnx::MatMul_2168_scale -> data_type: 1
#   onnx::MatMul_2168_zero_point -> data_type: 3
#   onnx::MatMul_2168_quantized -> data_type: 3
#   onnx::MatMul_2169_scale -> data_type: 1
#   onnx::MatMul_2169_zero_point -> data_type: 3
#   onnx::MatMul_2169_quantized -> data_type: 3
#   onnx::MatMul_2170_scale -> data_type: 1
#   onnx::MatMul_2170_zero_point -> data_type: 3
#   onnx::MatMul_2170_quantized -> data_type: 3
#   backbone.stage3.9.exp_dim_conv.weight_scale -> data_type: 1
#   backbone.stage3.9.exp_dim_conv.weight_zero_point -> data_type: 3
#   backbone.stage3.9.exp_dim_conv.weight_quantized -> data_type: 3
#   /backbone/stage3/stage3.9/exp_dim_conv/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.2.weight_scale -> data_type: 1
#   backbone.stage4.2.weight_zero_point -> data_type: 3
#   backbone.stage4.2.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.2/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.3.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage4.3.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage4.3.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage4.3.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage4.3.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage4.3.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.3/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.3.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage4.3.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage4.3.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2034_scale -> data_type: 1
#   onnx::Conv_2034_zero_point -> data_type: 3
#   onnx::Conv_2034_quantized -> data_type: 3
#   /backbone/stage4/stage4.3/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.4.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage4.4.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage4.4.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage4.4.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage4.4.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage4.4.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.4/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.4.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage4.4.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage4.4.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2037_scale -> data_type: 1
#   onnx::Conv_2037_zero_point -> data_type: 3
#   onnx::Conv_2037_quantized -> data_type: 3
#   /backbone/stage4/stage4.4/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.5.conv_block.conv1.weight_scale -> data_type: 1
#   backbone.stage4.5.conv_block.conv1.weight_zero_point -> data_type: 3
#   backbone.stage4.5.conv_block.conv1.weight_quantized -> data_type: 3
#   backbone.stage4.5.conv_block.conv1pw.weight_scale -> data_type: 1
#   backbone.stage4.5.conv_block.conv1pw.weight_zero_point -> data_type: 3
#   backbone.stage4.5.conv_block.conv1pw.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.5/conv_block/conv1pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.5.conv_block.conv2.weight_scale -> data_type: 1
#   backbone.stage4.5.conv_block.conv2.weight_zero_point -> data_type: 3
#   backbone.stage4.5.conv_block.conv2.weight_quantized -> data_type: 3
#   onnx::Conv_2040_scale -> data_type: 1
#   onnx::Conv_2040_zero_point -> data_type: 3
#   onnx::Conv_2040_quantized -> data_type: 3
#   /backbone/stage4/stage4.5/conv_block/conv2pw/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.7.red_dim_conv.0.weight_scale -> data_type: 1
#   backbone.stage4.7.red_dim_conv.0.weight_zero_point -> data_type: 3
#   backbone.stage4.7.red_dim_conv.0.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.7/red_dim_conv/red_dim_conv.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.7.tcm.0.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage4.7.tcm.0.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage4.7.tcm.0.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.7/tcm/tcm.0/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.7.tcm.0.pwconv1.weight_scale -> data_type: 1
#   backbone.stage4.7.tcm.0.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage4.7.tcm.0.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.7/tcm/tcm.0/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.7.tcm.1.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage4.7.tcm.1.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage4.7.tcm.1.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.7/tcm/tcm.1/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.7.tcm.1.pwconv1.weight_scale -> data_type: 1
#   backbone.stage4.7.tcm.1.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage4.7.tcm.1.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.7/tcm/tcm.1/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.7.tcm.2.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage4.7.tcm.2.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage4.7.tcm.2.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.7/tcm/tcm.2/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.7.tcm.2.pwconv1.weight_scale -> data_type: 1
#   backbone.stage4.7.tcm.2.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage4.7.tcm.2.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.7/tcm/tcm.2/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.7.tcm.3.dwconvs.0.weight_scale -> data_type: 1
#   backbone.stage4.7.tcm.3.dwconvs.0.weight_zero_point -> data_type: 3
#   backbone.stage4.7.tcm.3.dwconvs.0.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.7/tcm/tcm.3/dwconvs.0/Conv_output_0_bias_reshape_shape -> data_type: 7
#   backbone.stage4.7.tcm.3.pwconv1.weight_scale -> data_type: 1
#   backbone.stage4.7.tcm.3.pwconv1.weight_zero_point -> data_type: 3
#   backbone.stage4.7.tcm.3.pwconv1.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.7/tcm/tcm.3/pwconv1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   onnx::MatMul_2179_scale -> data_type: 1
#   onnx::MatMul_2179_zero_point -> data_type: 3
#   onnx::MatMul_2179_quantized -> data_type: 3
#   onnx::MatMul_2180_scale -> data_type: 1
#   onnx::MatMul_2180_zero_point -> data_type: 3
#   onnx::MatMul_2180_quantized -> data_type: 3
#   onnx::MatMul_2187_scale -> data_type: 1
#   onnx::MatMul_2187_zero_point -> data_type: 3
#   onnx::MatMul_2187_quantized -> data_type: 3
#   onnx::MatMul_2199_scale -> data_type: 1
#   onnx::MatMul_2199_zero_point -> data_type: 3
#   onnx::MatMul_2199_quantized -> data_type: 3
#   onnx::MatMul_2200_scale -> data_type: 1
#   onnx::MatMul_2200_zero_point -> data_type: 3
#   onnx::MatMul_2200_quantized -> data_type: 3
#   onnx::MatMul_2201_scale -> data_type: 1
#   onnx::MatMul_2201_zero_point -> data_type: 3
#   onnx::MatMul_2201_quantized -> data_type: 3
#   backbone.stage4.7.exp_dim_conv.weight_scale -> data_type: 1
#   backbone.stage4.7.exp_dim_conv.weight_zero_point -> data_type: 3
#   backbone.stage4.7.exp_dim_conv.weight_quantized -> data_type: 3
#   /backbone/stage4/stage4.7/exp_dim_conv/Conv_output_0_bias_reshape_shape -> data_type: 7
#   pool.linear1.weight_scale -> data_type: 1
#   pool.linear1.weight_zero_point -> data_type: 3
#   pool.linear1.weight_quantized -> data_type: 3
#   /pool/linear1/Conv_output_0_bias_reshape_shape -> data_type: 7
#   pool.linear2.weight_scale -> data_type: 1
#   pool.linear2.weight_zero_point -> data_type: 3
#   pool.linear2.weight_quantized -> data_type: 3
#   /pool/linear2/Conv_output_0_bias_reshape_shape -> data_type: 7
#   linear.weight_scale -> data_type: 1
#   linear.weight_zero_point -> data_type: 3
#   linear.weight_quantized -> data_type: 3

# %% [markdown]
# data_type = 1 in the ONNX initializer means float32.
#
# data_type: 3 (INT8) or data_type: 2 (UINT8)
