# %%
# %%capture --no-display 
# %load_ext autoreload
# %autoreload 2
## load all our utils
from utils.common_import import *

# %% [markdown]
# run last notebook to get torch model to that scope

# %%
# %%capture --no-display
import my_utils as myUtils
from play1_setBase_line_B0 import original_model,base_line_embedding
from play4_rknn_2dFix import model_no_mel,onnx_embedding
# Out:
# 2025-06-18 18:33:54.892636088 [W:onnxruntime:, constant_folding.cc:268 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sub node '/pool/Sub_1'
# 2025-06-18 18:33:54.909900933 [W:onnxruntime:, constant_folding.cc:268 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sub node '/pool/Sub_1'
# 2025-06-18 18:33:55.346429855 [W:onnxruntime:, constant_folding.cc:268 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sub node '/pool/Sub_1'
# 2025-06-18 18:33:55.364229770 [W:onnxruntime:, constant_folding.cc:268 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sub node '/pool/Sub_1'
# 2025-06-18 18:33:55.833691739 [W:onnxruntime:, constant_folding.cc:268 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sub node '/pool/Sub_1'
# 2025-06-18 18:33:55.849301453 [W:onnxruntime:, constant_folding.cc:268 ApplyImpl] Could not find a CPU kernel and hence can't constant fold Sub node '/pool/Sub_1'
# ...

# %%
myUtils.audio_wav_to_waveform
# Out:
# <function my_utils.audio_wav_to_waveform(wav_path)>

# %%
model_no_mel
# Out:
# ReDimNetNoMel(
#   (backbone): ReDimNet(
#     (stem): Sequential(
#       (0): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): LayerNorm(C=(10,), data_format=channels_first, eps=1e-06)
#       (2): to1d()
#     )
#     (stage0): Sequential(
#       (0): weigth1d(w=(1, 1, 1, 1),sequential=False)
#       (1): to2d(f=60,c=10)
#       (2): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#       (3): ConvBlock2d(
#         (conv_block): ResBasicBlock(
#           (conv1): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=10, bias=False)
#           (conv1pw): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
#           (bn1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=10, bias=False)
#           (conv2pw): Conv2d(10, 10, kernel_size=(1, 1), stride=(1, 1))
# ...
