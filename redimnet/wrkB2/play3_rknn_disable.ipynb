# %% [markdown]
# # ReDimNetNoMel Disable bad layers
#
# ===============================================================
#
# * build new noMel model based on base line
# * turn off bad layers that not converting to identity
# * store to onnx and test to convert
# * no need to run voice through as the identity layers kill the wights and the model output is garbage
# ===============================================================

# %%
# %load_ext autoreload
# %autoreload 2
## our utils
from utils.common_import import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%capture --no-display
import my_utils as myUtils
from play1_setBase_line_B2 import original_model,base_line_embedding

# %% [markdown]
# ReDimNetWrap expects raw 16 kHz mono audio, exactly 32 000 samples

# %%
from torchinfo import summary
summary(original_model, input_size=(1, 32000))
# Out:
# ==============================================================================================================
# Layer (type:depth-idx)                                       Output Shape              Param #
# ==============================================================================================================
# ReDimNetWrap                                                 [1, 192]                  --
# ├─MelBanks: 1-1                                              [1, 72, 134]              --
# │    └─Sequential: 2-1                                       [1, 72, 134]              --
# │    │    └─Identity: 3-1                                    [1, 32000]                --
# │    │    └─PreEmphasis: 3-2                                 [1, 32000]                --
# │    │    └─MelSpectrogram: 3-3                              [1, 72, 134]              --
# ├─ReDimNet: 1-2                                              [1, 1152, 134]            --
# │    └─Sequential: 2-2                                       [1, 1152, 134]            --
# │    │    └─Conv2d: 3-4                                      [1, 16, 72, 134]          160
# │    │    └─LayerNorm: 3-5                                   [1, 16, 72, 134]          32
# │    │    └─to1d: 3-6                                        [1, 1152, 134]            --
# │    └─Sequential: 2-3                                       [1, 1152, 134]            --
# │    │    └─weigth1d: 3-7                                    [1, 1152, 134]            (1)
# │    │    └─to2d: 3-8                                        [1, 16, 72, 134]          --
# │    │    └─Conv2d: 3-9                                      [1, 16, 72, 134]          272
# │    │    └─ConvBlock2d: 3-10                                [1, 16, 72, 134]          896
# │    │    └─ConvBlock2d: 3-11                                [1, 16, 72, 134]          896
# │    │    └─to1d: 3-12                                       [1, 1152, 134]            --
# │    │    └─TimeContextBlock1d: 3-13                         [1, 1152, 134]            279,648
# │    └─Sequential: 2-4                                       [1, 1152, 134]            --
# │    │    └─weigth1d: 3-14                                   [1, 1152, 134]            2,304
# │    │    └─to2d: 3-15                                       [1, 16, 72, 134]          --
# │    │    └─Conv2d: 3-16                                     [1, 32, 36, 134]          1,056
# │    │    └─ConvBlock2d: 3-17                                [1, 32, 36, 134]          2,304
# │    │    └─ConvBlock2d: 3-18                                [1, 32, 36, 134]          2,304
# │    │    └─to1d: 3-19                                       [1, 1152, 134]            --
# │    │    └─TimeContextBlock1d: 3-20                         [1, 1152, 134]            279,648
# │    └─Sequential: 2-5                                       [1, 1152, 134]            --
# │    │    └─weigth1d: 3-21                                   [1, 1152, 134]            3,456
# │    │    └─to2d: 3-22                                       [1, 32, 36, 134]          --
# │    │    └─Conv2d: 3-23                                     [1, 32, 36, 134]          1,056
# │    │    └─ConvBlock2d: 3-24                                [1, 32, 36, 134]          2,304
# │    │    └─ConvBlock2d: 3-25                                [1, 32, 36, 134]          2,304
# │    │    └─ConvBlock2d: 3-26                                [1, 32, 36, 134]          2,304
# │    │    └─to1d: 3-27                                       [1, 1152, 134]            --
# │    │    └─TimeContextBlock1d: 3-28                         [1, 1152, 134]            279,648
# │    └─Sequential: 2-6                                       [1, 1152, 134]            --
# │    │    └─weigth1d: 3-29                                   [1, 1152, 134]            4,608
# │    │    └─to2d: 3-30                                       [1, 32, 36, 134]          --
# │    │    └─Conv2d: 3-31                                     [1, 96, 12, 134]          9,312
# │    │    └─ConvBlock2d: 3-32                                [1, 96, 12, 134]          13,056
# │    │    └─ConvBlock2d: 3-33                                [1, 96, 12, 134]          13,056
# │    │    └─ConvBlock2d: 3-34                                [1, 96, 12, 134]          13,056
# │    │    └─ConvBlock2d: 3-35                                [1, 96, 12, 134]          13,056
# │    │    └─to1d: 3-36                                       [1, 1152, 134]            --
# │    │    └─TimeContextBlock1d: 3-37                         [1, 1152, 134]            460,368
# │    └─Sequential: 2-7                                       [1, 1152, 134]            --
# │    │    └─weigth1d: 3-38                                   [1, 1152, 134]            5,760
# │    │    └─to2d: 3-39                                       [1, 96, 12, 134]          --
# │    │    └─Conv2d: 3-40                                     [1, 96, 12, 134]          9,312
# │    │    └─ConvBlock2d: 3-41                                [1, 96, 12, 134]          13,056
# │    │    └─ConvBlock2d: 3-42                                [1, 96, 12, 134]          13,056
# │    │    └─ConvBlock2d: 3-43                                [1, 96, 12, 134]          13,056
# │    │    └─ConvBlock2d: 3-44                                [1, 96, 12, 134]          13,056
# │    │    └─to1d: 3-45                                       [1, 1152, 134]            --
# │    │    └─TimeContextBlock1d: 3-46                         [1, 1152, 134]            460,368
# │    └─Sequential: 2-8                                       [1, 1152, 134]            --
# │    │    └─weigth1d: 3-47                                   [1, 1152, 134]            6,912
# │    │    └─to2d: 3-48                                       [1, 96, 12, 134]          --
# │    │    └─Conv2d: 3-49                                     [1, 192, 6, 134]          37,056
# │    │    └─ConvBlock2d: 3-50                                [1, 192, 6, 134]          44,544
# │    │    └─ConvBlock2d: 3-51                                [1, 192, 6, 134]          44,544
# │    │    └─ConvBlock2d: 3-52                                [1, 192, 6, 134]          44,544
# │    │    └─ConvBlock2d: 3-53                                [1, 192, 6, 134]          44,544
# │    │    └─to1d: 3-54                                       [1, 1152, 134]            --
# │    │    └─TimeContextBlock1d: 3-55                         [1, 1152, 134]            1,168,416
# │    └─weigth1d: 2-9                                         [1, 1152, 134]            8,064
# │    └─Identity: 2-10                                        [1, 1152, 134]            --
# │    └─Identity: 2-11                                        [1, 1152, 134]            --
# ├─ASTP: 1-3                                                  [1, 2304]                 --
# │    └─Conv1d: 2-12                                          [1, 128, 134]             442,496
# │    └─Conv1d: 2-13                                          [1, 1152, 134]            148,608
# ├─BatchNorm1d: 1-4                                           [1, 2304]                 4,608
# ├─Linear: 1-5                                                [1, 192]                  442,560
# ==============================================================================================================
# Total params: 4,351,665
# Trainable params: 4,351,664
# Non-trainable params: 1
# Total mult-adds (M): 800.68
# ==============================================================================================================
# Input size (MB): 0.13
# Forward/backward pass size (MB): 110.68
# Params size (MB): 17.41
# Estimated Total Size (MB): 128.22
# ==============================================================================================================

# %% [markdown]
# ## find bad layers
#
# problematic layer tree is:
#
# ```
# TimeContextBlock1d
# ├── red_dim_conv (Sequential)
# │   ├── Conv1d(600 → 60, kernel_size=1)
# │   └── LayerNorm(C=60, data_format=channels_first)
# ├── tcm (Sequential)
# │   ├── ConvNeXtLikeBlock (kernel=7)
# │   │   ├── dwconvs: Conv1d(60 → 60, kernel_size=7, groups=60)
# │   │   ├── norm: BatchNorm1d(60)
# │   │   ├── act: GELU
# │   │   └── pwconv1: Conv1d(60 → 60, kernel_size=1)
# │   ├── ConvNeXtLikeBlock (kernel=19)
# │   │   ├── dwconvs: Conv1d(60 → 60, kernel_size=19, groups=60)
# │   │   ├── norm: BatchNorm1d(60)
# │   │   ├── act: GELU
# │   │   └── pwconv1: Conv1d(60 → 60, kernel_size=1)
# │   ├── ConvNeXtLikeBlock (kernel=31)
# │   │   ├── dwconvs: Conv1d(60 → 60, kernel_size=31, groups=60)
# │   │   ├── norm: BatchNorm1d(60)
# │   │   ├── act: GELU
# │   │   └── pwconv1: Conv1d(60 → 60, kernel_size=1)
# │   ├── ConvNeXtLikeBlock (kernel=59)
# │   │   ├── dwconvs: Conv1d(60 → 60, kernel_size=59, groups=60)
# │   │   ├── norm: BatchNorm1d(60)
# │   │   ├── act: GELU
# │   │   └── pwconv1: Conv1d(60 → 60, kernel_size=1)
# │   └── TransformerEncoderLayer
# │       ├── attention (MultiHeadAttention)
# │       │   ├── k_proj: Linear(60 → 60)
# │       │   ├── v_proj: Linear(60 → 60)
# │       │   ├── q_proj: Linear(60 → 60)
# │       │   └── out_proj: Linear(60 → 60)
# │       ├── layer_norm: LayerNorm(60)
# │       ├── feed_forward
# │       │   ├── intermediate_dropout: Dropout(0.0)
# │       │   ├── intermediate_dense: Linear(60 → 60)
# │       │   ├── intermediate_act_fn: NewGELUActivation
# │       │   ├── output_dense: Linear(60 → 60)
# │       │   └── output_dropout: Dropout(0.0)
# │       └── final_layer_norm: LayerNorm(60)
# └── exp_dim_conv: Conv1d(60 → 600, kernel_size=1)
# ```

# %%
def find_modules_by_classname(model, classname: str):
    matches = []

    def _search(module, prefix=''):
        for name, child in module.named_children():
            full_name = f'{prefix}.{name}' if prefix else name
            if child.__class__.__name__ == classname:
                matches.append((full_name, child))
            _search(child, full_name)

    _search(model)
    return matches


# model = ReDimNet()
classname = "TimeContextBlock1d"
matches = find_modules_by_classname(original_model, classname)

for i, (path, layer) in enumerate(matches):
    print(f"[{i}] {path} → {layer.__class__.__name__}(")
# Out:
# [0] backbone.stage0.6 → TimeContextBlock1d(
# [1] backbone.stage1.6 → TimeContextBlock1d(
# [2] backbone.stage2.7 → TimeContextBlock1d(
# [3] backbone.stage3.8 → TimeContextBlock1d(
# [4] backbone.stage4.8 → TimeContextBlock1d(
# [5] backbone.stage5.8 → TimeContextBlock1d(

# %% [markdown]
# ##  new model with Identity layers

# %%
########################################
# 2) Define a Model Class without MelBanks
########################################
import torch
import torch.nn as nn

class ReDimNetNoMel(nn.Module):
    """
    A wrapper around the original ReDimNetWrap that:
      - Excludes the 'spec' (MelBanks) module
      - Uses 'backbone', 'pool', 'bn', and 'linear'
    We expect a precomputed mel spectrogram as input with shape [B, 1, n_mels, time_frames].
    """
    def __init__(self, original_wrap):
        super().__init__()
        
        # Grab references to the submodules we want to keep
        self.backbone = original_wrap.backbone
        
        # try: all layers of ConvNeXtLikeBlock
        for stage_idx, block_idx in [(0, 6), (1, 6), (2, 7), (3, 8), (4, 8) , (5, 8)]:
            for tcm_idx in range(4):  # tcm[0] to tcm[3] 
                # self.backbone.__getattr__(f'stage{stage_idx}')[block_idx].tcm[tcm_idx] = nn.Identity()            ## >>>> PASS
                # self.backbone.__getattr__(f'stage{stage_idx}')[block_idx].tcm[tcm_idx].act = nn.SiLU()            ## >>>> NOT PASS
                ## !!! all Conv1d
                self.backbone.__getattr__(f'stage{stage_idx}')[block_idx].tcm[tcm_idx].dwconvs[0] = nn.Identity()
                self.backbone.__getattr__(f'stage{stage_idx}')[block_idx].tcm[tcm_idx].pwconv1 = nn.Identity()
                ## >>>> PASS

        
        
        # Replace ASTP with RKNN-safe version:
        self.pool = original_wrap.pool
        self.bn = original_wrap.bn
        self.linear = original_wrap.linear

    def forward(self, x):
        # x: shape [B, 1, n_mels, time_frames]
        # (1) Pass through the backbone
        x = self.backbone(x)    # shape might become [B, channels, frames] or similar
        print("Backbone output shape:", x.shape)  # ADD THIS LINE
        # (2) Pooling
        x = self.pool(x)        # ASTP => shape likely [B, embedding_dim]
        # (3) BatchNorm
        x = self.bn(x)
        # (4) Final linear => 192-dim (if that's your embedding size)
        x = self.linear(x)
        return x


# Create an instance of our new model that skips the MelBanks front-end
model_no_mel = ReDimNetNoMel(original_model)

# %% [markdown]
# ### run to see if it works

# %%
model_no_mel.eval()  # <- this line is critical!
dummy = torch.randn(1, 1, 72, 200)
model_no_mel(dummy)
# Out:
# Backbone output shape: torch.Size([1, 1152, 200])
# tensor([[-0.0652, -0.6970,  1.1959, -2.0029,  1.7614,  0.9690, -1.7882, -1.2452,
#           4.0278, -1.4662, -0.4123,  0.0115, -1.1765,  0.5948, -1.1992,  1.1045,
#           1.3353, -1.2483, -2.1060,  0.8185,  0.6821,  0.6542, -0.7927, -1.0899,
#           2.2258, -2.6792, -0.3295,  1.0098, -2.5207,  0.2733,  0.0883,  1.5561,
#          -0.4259, -1.4513, -0.2319, -1.2865, -2.8042,  1.6346, -0.2778,  0.0300,
#           1.0930, -0.4534, -0.7703, -1.4452, -0.6968, -1.3758, -0.0780, -0.3094,
#          -0.8326, -0.3129,  1.8246,  1.9380,  0.6543,  0.2583, -0.5174,  1.1465,
#           0.2074,  0.2285, -0.1807, -0.6855, -0.3086, -1.5716,  1.2913, -0.1225,
#          -1.6333,  0.6647,  0.7337,  2.3451, -0.2833, -1.6306, -1.1414, -1.5993,
#          -0.6701,  3.3115, -1.2042,  1.7720,  0.3653,  2.2990,  0.2771,  0.3368,
#           2.1119, -0.5693, -1.2039, -0.1968,  0.4912, -0.2070,  0.2387,  0.3039,
#          -0.8871, -0.6586,  0.6221,  1.0567, -0.2817, -1.9561,  0.2828,  1.4142,
#          -1.9354,  0.6268,  1.0593,  0.6084, -2.1068, -0.0686,  0.1774,  0.4528,
#           0.2023,  0.9502,  1.8507,  2.0601,  0.2831, -0.4096, -0.7765,  0.8143,
#           0.1979,  0.2023, -0.6318,  1.3902,  1.6299, -2.0743, -1.0987, -0.1468,
#           0.0936, -0.6711, -1.8566, -1.3210,  0.3114,  0.7748, -0.6466, -0.2679,
#          -1.8348,  1.2718, -1.4171,  0.3334, -0.8494,  3.1535,  0.6559,  0.8869,
#           0.7545,  0.3260, -0.6920,  0.1977, -0.0328, -0.0337,  0.3548, -0.0440,
#           1.9412, -0.7670,  0.1476,  1.4133, -0.8898, -1.6620,  2.6871,  0.9229,
#          -0.3809, -0.8030,  0.7401, -3.2209, -1.0675, -1.0395, -0.5431, -1.6218,
#           1.7864, -0.3650, -1.6215, -0.0388, -0.6052, -0.0052, -2.1589, -0.6039,
#          -0.9180, -4.1718,  0.4052, -0.3442,  0.2148, -0.8888,  1.6353, -0.6703,
#          -1.5451,  0.0293,  1.5496,  0.3463, -0.3884,  0.7099,  2.8072, -0.5345,
#           0.6803,  1.0058,  1.1471,  0.6302, -2.4031,  0.9364,  0.6153, -1.1272]],
#        grad_fn=<AddmmBackward0>)

# %%
# print("stage0.6 =", model_no_mel.backbone.stage4[7].tcm[0]) 
print("stage0.6 =", model_no_mel.backbone.stage0[6].tcm[0])
# Out:
# stage0.6 = ConvNeXtLikeBlock(
#   (dwconvs): ModuleList(
#     (0): Identity()
#   )
#   (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act): GELU(approximate='none')
#   (pwconv1): Identity()
# )

# %% [markdown]
# ## info

# %%
model_no_mel.eval()
# Out:
# ReDimNetNoMel(
#   (backbone): ReDimNet(
#     (stem): Sequential(
#       (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#       (1): LayerNorm(C=(16,), data_format=channels_first, eps=1e-06)
#       (2): to1d()
#     )
#     (stage0): Sequential(
#       (0): weigth1d(w=(1, 1, 1, 1),sequential=False)
#       (1): to2d(f=72,c=16)
#       (2): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#       (3): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=4)
#           )
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=4)
#           )
#           (norm): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (5): to1d()
#       (6): TimeContextBlock1d(
#         (red_dim_conv): Sequential(
#           (0): Conv1d(1152, 96, kernel_size=(1,), stride=(1,))
#           (1): LayerNorm(C=(96,), data_format=channels_first, eps=1e-06)
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (1): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (2): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (3): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (4): TransformerEncoderLayer(
#             (attention): MultiHeadAttention(
#               (k_proj): Linear(in_features=96, out_features=96, bias=True)
#               (v_proj): Linear(in_features=96, out_features=96, bias=True)
#               (q_proj): Linear(in_features=96, out_features=96, bias=True)
#               (out_proj): Linear(in_features=96, out_features=96, bias=True)
#             )
#             (layer_norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (feed_forward): FeedForward(
#               (intermediate_dropout): Dropout(p=0.0, inplace=False)
#               (intermediate_dense): Linear(in_features=96, out_features=96, bias=True)
#               (intermediate_act_fn): NewGELUActivation()
#               (output_dense): Linear(in_features=96, out_features=96, bias=True)
#               (output_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (final_layer_norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#         )
#         (exp_dim_conv): Conv1d(96, 1152, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (stage1): Sequential(
#       (0): weigth1d(w=(1, 2, 1152, 1),sequential=False)
#       (1): to2d(f=72,c=16)
#       (2): Conv2d(16, 32, kernel_size=(2, 1), stride=(2, 1))
#       (3): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=8)
#           )
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=8)
#           )
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (5): to1d()
#       (6): TimeContextBlock1d(
#         (red_dim_conv): Sequential(
#           (0): Conv1d(1152, 96, kernel_size=(1,), stride=(1,))
#           (1): LayerNorm(C=(96,), data_format=channels_first, eps=1e-06)
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (1): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (2): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (3): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (4): TransformerEncoderLayer(
#             (attention): MultiHeadAttention(
#               (k_proj): Linear(in_features=96, out_features=96, bias=True)
#               (v_proj): Linear(in_features=96, out_features=96, bias=True)
#               (q_proj): Linear(in_features=96, out_features=96, bias=True)
#               (out_proj): Linear(in_features=96, out_features=96, bias=True)
#             )
#             (layer_norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (feed_forward): FeedForward(
#               (intermediate_dropout): Dropout(p=0.0, inplace=False)
#               (intermediate_dense): Linear(in_features=96, out_features=96, bias=True)
#               (intermediate_act_fn): NewGELUActivation()
#               (output_dense): Linear(in_features=96, out_features=96, bias=True)
#               (output_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (final_layer_norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#         )
#         (exp_dim_conv): Conv1d(96, 1152, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (stage2): Sequential(
#       (0): weigth1d(w=(1, 3, 1152, 1),sequential=False)
#       (1): to2d(f=36,c=32)
#       (2): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#       (3): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=8)
#           )
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=8)
#           )
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (5): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=8)
#           )
#           (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (6): to1d()
#       (7): TimeContextBlock1d(
#         (red_dim_conv): Sequential(
#           (0): Conv1d(1152, 96, kernel_size=(1,), stride=(1,))
#           (1): LayerNorm(C=(96,), data_format=channels_first, eps=1e-06)
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (1): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (2): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (3): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (4): TransformerEncoderLayer(
#             (attention): MultiHeadAttention(
#               (k_proj): Linear(in_features=96, out_features=96, bias=True)
#               (v_proj): Linear(in_features=96, out_features=96, bias=True)
#               (q_proj): Linear(in_features=96, out_features=96, bias=True)
#               (out_proj): Linear(in_features=96, out_features=96, bias=True)
#             )
#             (layer_norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#             (feed_forward): FeedForward(
#               (intermediate_dropout): Dropout(p=0.0, inplace=False)
#               (intermediate_dense): Linear(in_features=96, out_features=96, bias=True)
#               (intermediate_act_fn): NewGELUActivation()
#               (output_dense): Linear(in_features=96, out_features=96, bias=True)
#               (output_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (final_layer_norm): LayerNorm((96,), eps=1e-06, elementwise_affine=True)
#           )
#         )
#         (exp_dim_conv): Conv1d(96, 1152, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (stage3): Sequential(
#       (0): weigth1d(w=(1, 4, 1152, 1),sequential=False)
#       (1): to2d(f=36,c=32)
#       (2): Conv2d(32, 96, kernel_size=(3, 1), stride=(3, 1))
#       (3): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=24)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=24)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (5): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=24)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (6): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=24)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (7): to1d()
#       (8): TimeContextBlock1d(
#         (red_dim_conv): Sequential(
#           (0): Conv1d(1152, 144, kernel_size=(1,), stride=(1,))
#           (1): LayerNorm(C=(144,), data_format=channels_first, eps=1e-06)
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (1): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (2): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (3): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (4): TransformerEncoderLayer(
#             (attention): MultiHeadAttention(
#               (k_proj): Linear(in_features=144, out_features=144, bias=True)
#               (v_proj): Linear(in_features=144, out_features=144, bias=True)
#               (q_proj): Linear(in_features=144, out_features=144, bias=True)
#               (out_proj): Linear(in_features=144, out_features=144, bias=True)
#             )
#             (layer_norm): LayerNorm((144,), eps=1e-06, elementwise_affine=True)
#             (feed_forward): FeedForward(
#               (intermediate_dropout): Dropout(p=0.0, inplace=False)
#               (intermediate_dense): Linear(in_features=144, out_features=144, bias=True)
#               (intermediate_act_fn): NewGELUActivation()
#               (output_dense): Linear(in_features=144, out_features=144, bias=True)
#               (output_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (final_layer_norm): LayerNorm((144,), eps=1e-06, elementwise_affine=True)
#           )
#         )
#         (exp_dim_conv): Conv1d(144, 1152, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (stage4): Sequential(
#       (0): weigth1d(w=(1, 5, 1152, 1),sequential=False)
#       (1): to2d(f=12,c=96)
#       (2): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#       (3): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=24)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=24)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (5): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=24)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (6): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=24)
#           )
#           (norm): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (7): to1d()
#       (8): TimeContextBlock1d(
#         (red_dim_conv): Sequential(
#           (0): Conv1d(1152, 144, kernel_size=(1,), stride=(1,))
#           (1): LayerNorm(C=(144,), data_format=channels_first, eps=1e-06)
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (1): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (2): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (3): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (4): TransformerEncoderLayer(
#             (attention): MultiHeadAttention(
#               (k_proj): Linear(in_features=144, out_features=144, bias=True)
#               (v_proj): Linear(in_features=144, out_features=144, bias=True)
#               (q_proj): Linear(in_features=144, out_features=144, bias=True)
#               (out_proj): Linear(in_features=144, out_features=144, bias=True)
#             )
#             (layer_norm): LayerNorm((144,), eps=1e-06, elementwise_affine=True)
#             (feed_forward): FeedForward(
#               (intermediate_dropout): Dropout(p=0.0, inplace=False)
#               (intermediate_dense): Linear(in_features=144, out_features=144, bias=True)
#               (intermediate_act_fn): NewGELUActivation()
#               (output_dense): Linear(in_features=144, out_features=144, bias=True)
#               (output_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (final_layer_norm): LayerNorm((144,), eps=1e-06, elementwise_affine=True)
#           )
#         )
#         (exp_dim_conv): Conv1d(144, 1152, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (stage5): Sequential(
#       (0): weigth1d(w=(1, 6, 1152, 1),sequential=False)
#       (1): to2d(f=12,c=96)
#       (2): Conv2d(96, 192, kernel_size=(2, 1), stride=(2, 1))
#       (3): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=48)
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (4): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=48)
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (5): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=48)
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (6): ConvBlock2d(
#         (conv_block): ConvNeXtLikeBlock(
#           (dwconvs): ModuleList(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=same, groups=48)
#           )
#           (norm): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): GELU(approximate='none')
#           (pwconv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (7): to1d()
#       (8): TimeContextBlock1d(
#         (red_dim_conv): Sequential(
#           (0): Conv1d(1152, 288, kernel_size=(1,), stride=(1,))
#           (1): LayerNorm(C=(288,), data_format=channels_first, eps=1e-06)
#         )
#         (tcm): Sequential(
#           (0): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (1): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (2): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (3): ConvNeXtLikeBlock(
#             (dwconvs): ModuleList(
#               (0): Identity()
#             )
#             (norm): BatchNorm1d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): GELU(approximate='none')
#             (pwconv1): Identity()
#           )
#           (4): TransformerEncoderLayer(
#             (attention): MultiHeadAttention(
#               (k_proj): Linear(in_features=288, out_features=288, bias=True)
#               (v_proj): Linear(in_features=288, out_features=288, bias=True)
#               (q_proj): Linear(in_features=288, out_features=288, bias=True)
#               (out_proj): Linear(in_features=288, out_features=288, bias=True)
#             )
#             (layer_norm): LayerNorm((288,), eps=1e-06, elementwise_affine=True)
#             (feed_forward): FeedForward(
#               (intermediate_dropout): Dropout(p=0.0, inplace=False)
#               (intermediate_dense): Linear(in_features=288, out_features=288, bias=True)
#               (intermediate_act_fn): NewGELUActivation()
#               (output_dense): Linear(in_features=288, out_features=288, bias=True)
#               (output_dropout): Dropout(p=0.0, inplace=False)
#             )
#             (final_layer_norm): LayerNorm((288,), eps=1e-06, elementwise_affine=True)
#           )
#         )
#         (exp_dim_conv): Conv1d(288, 1152, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (fin_wght1d): weigth1d(w=(1, 7, 1152, 1),sequential=False)
#     (mfa): Identity()
#     (fin_to2d): Identity()
#   )
#   (pool): ASTP(
#     (linear1): Conv1d(3456, 128, kernel_size=(1,), stride=(1,))
#     (linear2): Conv1d(128, 1152, kernel_size=(1,), stride=(1,))
#   )
#   (bn): BatchNorm1d(2304, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear): Linear(in_features=2304, out_features=192, bias=True)
# )

# %%
summary(model_no_mel, (1, 1, 72, 200))
# Out:
# Backbone output shape: torch.Size([1, 1152, 200])
# ==============================================================================================================
# Layer (type:depth-idx)                                       Output Shape              Param #
# ==============================================================================================================
# ReDimNetNoMel                                                [1, 192]                  --
# ├─ReDimNet: 1-1                                              [1, 1152, 200]            --
# │    └─Sequential: 2-1                                       [1, 1152, 200]            --
# │    │    └─Conv2d: 3-1                                      [1, 16, 72, 200]          160
# │    │    └─LayerNorm: 3-2                                   [1, 16, 72, 200]          32
# │    │    └─to1d: 3-3                                        [1, 1152, 200]            --
# │    └─Sequential: 2-2                                       [1, 1152, 200]            --
# │    │    └─weigth1d: 3-4                                    [1, 1152, 200]            (1)
# │    │    └─to2d: 3-5                                        [1, 16, 72, 200]          --
# │    │    └─Conv2d: 3-6                                      [1, 16, 72, 200]          272
# │    │    └─ConvBlock2d: 3-7                                 [1, 16, 72, 200]          896
# │    │    └─ConvBlock2d: 3-8                                 [1, 16, 72, 200]          896
# │    │    └─to1d: 3-9                                        [1, 1152, 200]            --
# │    │    └─TimeContextBlock1d: 3-10                         [1, 1152, 200]            279,648
# │    └─Sequential: 2-3                                       [1, 1152, 200]            --
# │    │    └─weigth1d: 3-11                                   [1, 1152, 200]            2,304
# │    │    └─to2d: 3-12                                       [1, 16, 72, 200]          --
# │    │    └─Conv2d: 3-13                                     [1, 32, 36, 200]          1,056
# │    │    └─ConvBlock2d: 3-14                                [1, 32, 36, 200]          2,304
# │    │    └─ConvBlock2d: 3-15                                [1, 32, 36, 200]          2,304
# │    │    └─to1d: 3-16                                       [1, 1152, 200]            --
# │    │    └─TimeContextBlock1d: 3-17                         [1, 1152, 200]            279,648
# │    └─Sequential: 2-4                                       [1, 1152, 200]            --
# │    │    └─weigth1d: 3-18                                   [1, 1152, 200]            3,456
# │    │    └─to2d: 3-19                                       [1, 32, 36, 200]          --
# │    │    └─Conv2d: 3-20                                     [1, 32, 36, 200]          1,056
# │    │    └─ConvBlock2d: 3-21                                [1, 32, 36, 200]          2,304
# │    │    └─ConvBlock2d: 3-22                                [1, 32, 36, 200]          2,304
# │    │    └─ConvBlock2d: 3-23                                [1, 32, 36, 200]          2,304
# │    │    └─to1d: 3-24                                       [1, 1152, 200]            --
# │    │    └─TimeContextBlock1d: 3-25                         [1, 1152, 200]            279,648
# │    └─Sequential: 2-5                                       [1, 1152, 200]            --
# │    │    └─weigth1d: 3-26                                   [1, 1152, 200]            4,608
# │    │    └─to2d: 3-27                                       [1, 32, 36, 200]          --
# │    │    └─Conv2d: 3-28                                     [1, 96, 12, 200]          9,312
# │    │    └─ConvBlock2d: 3-29                                [1, 96, 12, 200]          13,056
# │    │    └─ConvBlock2d: 3-30                                [1, 96, 12, 200]          13,056
# │    │    └─ConvBlock2d: 3-31                                [1, 96, 12, 200]          13,056
# │    │    └─ConvBlock2d: 3-32                                [1, 96, 12, 200]          13,056
# │    │    └─to1d: 3-33                                       [1, 1152, 200]            --
# │    │    └─TimeContextBlock1d: 3-34                         [1, 1152, 200]            460,368
# │    └─Sequential: 2-6                                       [1, 1152, 200]            --
# │    │    └─weigth1d: 3-35                                   [1, 1152, 200]            5,760
# │    │    └─to2d: 3-36                                       [1, 96, 12, 200]          --
# │    │    └─Conv2d: 3-37                                     [1, 96, 12, 200]          9,312
# │    │    └─ConvBlock2d: 3-38                                [1, 96, 12, 200]          13,056
# │    │    └─ConvBlock2d: 3-39                                [1, 96, 12, 200]          13,056
# │    │    └─ConvBlock2d: 3-40                                [1, 96, 12, 200]          13,056
# │    │    └─ConvBlock2d: 3-41                                [1, 96, 12, 200]          13,056
# │    │    └─to1d: 3-42                                       [1, 1152, 200]            --
# │    │    └─TimeContextBlock1d: 3-43                         [1, 1152, 200]            460,368
# │    └─Sequential: 2-7                                       [1, 1152, 200]            --
# │    │    └─weigth1d: 3-44                                   [1, 1152, 200]            6,912
# │    │    └─to2d: 3-45                                       [1, 96, 12, 200]          --
# │    │    └─Conv2d: 3-46                                     [1, 192, 6, 200]          37,056
# │    │    └─ConvBlock2d: 3-47                                [1, 192, 6, 200]          44,544
# │    │    └─ConvBlock2d: 3-48                                [1, 192, 6, 200]          44,544
# │    │    └─ConvBlock2d: 3-49                                [1, 192, 6, 200]          44,544
# │    │    └─ConvBlock2d: 3-50                                [1, 192, 6, 200]          44,544
# │    │    └─to1d: 3-51                                       [1, 1152, 200]            --
# │    │    └─TimeContextBlock1d: 3-52                         [1, 1152, 200]            1,168,416
# │    └─weigth1d: 2-8                                         [1, 1152, 200]            8,064
# │    └─Identity: 2-9                                         [1, 1152, 200]            --
# │    └─Identity: 2-10                                        [1, 1152, 200]            --
# ├─ASTP: 1-2                                                  [1, 2304]                 --
# │    └─Conv1d: 2-11                                          [1, 128, 200]             442,496
# │    └─Conv1d: 2-12                                          [1, 1152, 200]            148,608
# ├─BatchNorm1d: 1-3                                           [1, 2304]                 4,608
# ├─Linear: 1-4                                                [1, 192]                  442,560
# ==============================================================================================================
# Total params: 4,351,665
# Trainable params: 4,351,664
# Non-trainable params: 1
# Total mult-adds (G): 1.19
# ==============================================================================================================
# Input size (MB): 0.06
# Forward/backward pass size (MB): 165.19
# Params size (MB): 17.41
# Estimated Total Size (MB): 182.66
# ==============================================================================================================

# %% [markdown]
# ## store

# %%
myUtils.export_to_onnx(model_no_mel,onnx_path = "ReDimNet_no_mel.onnx")
# !ls -lah ReDimNet_no_mel.onnx
# Out:
# Backbone output shape: torch.Size([1, 1152, 134])
# Backbone output shape: torch.Size([1, 1152, 134])
# Exported NHWC model to ReDimNet_no_mel_nhwc.onnx
# Exported to ReDimNet_no_mel.onnx
# -rw-rw-r-- 1 vlad vlad 17M Jul  6 06:53 ReDimNet_no_mel.onnx

# %%
import onnx
onnx_model = onnx.load("ReDimNet_no_mel.onnx")
onnx.checker.check_model(onnx_model)
print("ONNX model is valid!")
# Out:
# ONNX model is valid!
